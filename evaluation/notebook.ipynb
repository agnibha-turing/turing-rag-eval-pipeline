# %% [markdown]
# # Evaluate a RAG application
#
# This example uses [Langchain](https://www.langchain.com) and [Giskard](https://github.com/Giskard-AI/giskard) to evaluate the quality of a RAG application.

# %%
import os
from dotenv import load_dotenv

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
MODEL = "gpt-3.5-turbo"

# %% [markdown]
# ## Scrape the Website and Split the Content

# %%
# from langchain_community.document_loaders import WebBaseLoader
# from langchain.text_splitter import RecursiveCharacterTextSplitter

# text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=20)

# loader = WebBaseLoader("https://www.ml.school/")
# documents = loader.load_and_split(text_splitter)
# documents
# Out:
# [Document(metadata={'source': 'https://www.ml.school/', 'title': "Building Machine Learning Systems That Don't Suck", 'description': "A live, interactive program that'll help you build production-ready machine learning systems from the ground up.", 'language': 'en'}, page_content='Building Machine Learning Systems That Don\'t Suck"This is the best machine learning course I\'ve done. Worth every cent."Jose Reyes, AI/ML at Cevo AustraliaBuilding Machine Learning Systems That Don\'t SuckA live, interactive program that\'ll help you build production-ready machine learning systems from the ground up.Next cohort:\xa0February 3 - 20, 2025Check the schedule for more details about upcoming cohorts.I want to join!Sign inLearn how to design, build, deploy, and scale machine learning systems to solve real-world problems.I\'ll lose my mind if I see another book or course teaching people the same basic ideas for the hundredth time. Most people are stuck in beginner mode, and finding help to solve real-world problems is hard.I want to change that.I started writing software 30 years ago. I\'ve written pipelines and trained models for some of the largest companies in the world. I want to show you how to do the same.This is the class I wish I had taken when I started.This program will'),
#  Document(metadata={'source': 'https://www.ml.school/', 'title': "Building Machine Learning Systems That Don't Suck", 'description': "A live, interactive program that'll help you build production-ready machine learning systems from the ground up.", 'language': 'en'}, page_content="program will help you unlearn what you think machine learning is. It's a practical, hands-on class where you'll learn from years of experience and real-world examples.When you join, you get lifetime access to the following:18 hours of live, interactive sessions. We'll use this time to discuss the first principles behind building machine learning systems.10 hours of step-by-step coding instructions. These practical sessions will show you how to build an end-to-end system from scratch.A final project where you'll build a complete solution and receive direct feedback on your work.100 coding assignments and practice questions.The entire source code of a working production system. It's yours. You can change and use it as you see fit.A private community where you'll collaborate with thousands of people from different backgrounds.Direct access to your instructor.Lifetime access to every past and future cohort.Program certificate upon completion.And the best part is that you only pay once to"),
#  Document(metadata={'source': 'https://www.ml.school/', 'title': "Building Machine Learning Systems That Don't Suck", 'description': "A live, interactive program that'll help you build production-ready machine learning systems from the ground up.", 'language': 'en'}, page_content="only pay once to join. There are no monthly fees. No annual fees. No hidden costs. You pay once to join and benefit forever until the end of time.The program won't be easy. It'll take time and effort. But if you want to use machine learning to solve real-world problems, this is the class you don't want to miss.Who Is This Program For?This is a practical, hands-on program for technical professionals who are ready to put in the work.This program is for software engineers, data scientists, data analysts, machine learning engineers, technical managers, and anyone anyone who wants to use machine learning to solve real-world problems.Here are the criteria to succeed in the program:You have experience writing code. We'll use Python throughout the class, but you won't have any problems if you know any other language.You are familiar with basic machine learning terminology. This is not an introductory class. We'll move quickly over the basics to focus on the fundamental ideas that make systems"),
#  Document(metadata={'source': 'https://www.ml.school/', 'title': "Building Machine Learning Systems That Don't Suck", 'description': "A live, interactive program that'll help you build production-ready machine learning systems from the ground up.", 'language': 'en'}, page_content='that make systems work.You are ready to put in the work to succeed."I have learned a ton from Santiago in his class and it was actually what helped inspire me and get into the MLOps work that I\'m doing now. Truly one of the most helpful online courses for doing real, full-scale machine learning."Brian H. HoughSoftware EngineerWhat Will You Learn?You\'ll come out with practical skills and insights into what it takes to build systems that work in the real world.Here is a summary of what makes this program unique:You\'ll design and write the code to build an end-to-end machine learning system starting from scratch.You\'ll learn best practices to tackle the most significant challenges machine learning engineers face to build, evaluate, run, monitor, and maintain machine learning systems in real-world scenarios.You\'ll learn how to use techniques like active learning, distributed training, adversarial validation, human-in-the-loop deployments, model compression, test-time augmentation, testing'),
#  Document(metadata={'source': 'https://www.ml.school/', 'title': "Building Machine Learning Systems That Don't Suck", 'description': "A live, interactive program that'll help you build production-ready machine learning systems from the ground up.", 'language': 'en'}, page_content="testing in production, among many others.You'll learn how to create training, deploying, monitoring, and inference pipelines using Amazon SageMaker and open-source tools.Forget about theoretical concepts. This program will show you some of the things I've learned from real-life examples I've built during more than 30 years in the industry.Check the program syllabus\xa0→Real-life examples and case studiesLearn from practical experience building machine learning systems that work in the real world.Live, interactive sessionsAsk questions and interact with the instructor and other students in real time.Code walkthroughsStep by step coding instructions to help you build a production system from scratch.Upcoming ScheduleEvery iteration of the program gives you 18 hours of hands-on, live training spread over 3 weeks.Here are the upcoming cohorts:Cohort 17: February 3 - February 20, 2025. 10:00 AM ESTLive sessions will take place every Monday and Thursday at the same time. On Wednesdays, we'll"),
#  Document(metadata={'source': 'https://www.ml.school/', 'title': "Building Machine Learning Systems That Don't Suck", 'description': "A live, interactive program that'll help you build production-ready machine learning systems from the ground up.", 'language': 'en'}, page_content='Wednesdays, we\'ll host office hours when you can bring your questions projects or anything else you want to discuss.Monday: Live session. 2 hours.Tuesday: Individual work.Wednesday: Optional office hours.Thursday: Live session. 2 hours.Friday: Individual work.Do not wait for a specific cohort to join the program. You have lifetime access to every past and future cohort, and the sooner you join, the more time you have to prepare.Every session is recorded. You can attend live or watch the recorded version later."This is one of the best classes I\'ve ever purchased over the internet. Santiago is a terrific teacher. The ability he has to share knowledge is fantastic. I recommend this course. Worth 10x what he\'s charging."Sal DiStefanoReady To Join The Program?You\'ll get lifetime access. No monthly fees. No annual fees. No hidden costs.$500$300Pay once. Access forever.Pay once to join the program and get lifetime access. You can participate in as many iterations as you\'d like. No'),
#  Document(metadata={'source': 'https://www.ml.school/', 'title': "Building Machine Learning Systems That Don't Suck", 'description': "A live, interactive program that'll help you build production-ready machine learning systems from the ground up.", 'language': 'en'}, page_content="as you'd like. No restrictions.Enjoy 18 hours of live, interactive sessionsWatch 10 hours of step-by-step coding instructionsPractice with 100 coding assignmentsAccess the complete source code of a production systemLearn how to start freelancing on UpworkGet feedback and support from the communityGet direct feedback from your instructorJoin nowProgram SyllabusThis program will teach you the practical skills and insights that will help you build machine learning systems.Here are the contents of the six live sessions of the program:Session 1 - How To Start (Almost) Any ProjectWhat makes production machine learning different from what you've learned.The strategy to solve the right problem using the right solution.Critical questions to ask before starting any project.Problem framing, inversion, and the haystack principle for building successful applications.The first rule of machine learning engineering and how to start building.Data collection strategies. A technique to determine how"),
#  Document(metadata={'source': 'https://www.ml.school/', 'title': "Building Machine Learning Systems That Don't Suck", 'description': "A live, interactive program that'll help you build production-ready machine learning systems from the ground up.", 'language': 'en'}, page_content='to determine how much data you need.The problem of selection bias and how to deal with it.Labeling data. Human annotations, natural labels and weak supervision.Active learning using the uncertainty and diversity sampling strategies.Session 2 - How to Build a ModelThe role of data cleaning and feature engineering to build better models.Turning data into numbers using vectorization techniques.Producing homogeneous features using normalization and standardization.Handling and interpreting missing values using imputation techniques.The approach to choosing the best model to solve any problem.Random baselines and the zero-rule algorithm.How to use overfitting to build models that don\'t suck.Hyperparameter tuning and experiment tracking.Measuring the quality of your holdout set.An introduction to distributed training using data parallelism and model parallelism.See the remaining sessions"This is an awesome course! This is my second round and I continue learning. I recommend it with complete'),
#  Document(metadata={'source': 'https://www.ml.school/', 'title': "Building Machine Learning Systems That Don't Suck", 'description': "A live, interactive program that'll help you build production-ready machine learning systems from the ground up.", 'language': 'en'}, page_content='it with complete confidence."Juan OlanoMachine Learning EngineerFrequently Asked QuestionsIf you can\'t find the answer to your question, please reach out on social media and I\'ll be happy to help.How long will it take to complete the program?If you are attending the live sessions, you should set aside a minimum of 4 hours every week during the three weeks of the program. This commitment will be enough for engineer leaders or anyone not interested in the coding portion of the program.Those interested in implementing the concepts discussed in class should set aside 2 to 4 hours weekly to complete the code walkthroughs and work on the assignments.Are live sessions recorded?Yes, we record every live session. You can decide when to attend classes live or catch up asynchronously later using the recording.I\'m a complete beginner. Is this program helpful for me?This program is not an introduction to machine learning.While we\'ll discuss many fundamental ideas behind machine learning, beginners'),
#  Document(metadata={'source': 'https://www.ml.school/', 'title': "Building Machine Learning Systems That Don't Suck", 'description': "A live, interactive program that'll help you build production-ready machine learning systems from the ground up.", 'language': 'en'}, page_content='learning, beginners will find the sessions go much faster than what\'s optimal for them.What does "lifetime access" mean?You only pay once to join the program and get immediate access to every past, present, and future cohort.Every new iteration of the program is better than the ones before. Many students take classes once and then join a later cohort to benefit from the updates.The lifetime access removes any pressure from having to complete the program when life gets in the way.Hey! I\'m Santiago.I\'m the instructor of the program.I\'m a machine learning engineer with over two decades of experience building and scaling enterprise software and machine learning systems.I love neural networks. I love to make them work at scale.From 2009 to 2023, I built products for Disney, Boston Dynamics, IBM, Dell, G4S, Anheuser-Busch, and NextEra Energy, among other clients. I learned about trade-offs and how to create products that work.I started this program in March 2023. Since then, thousands of'),
#  Document(metadata={'source': 'https://www.ml.school/', 'title': "Building Machine Learning Systems That Don't Suck", 'description': "A live, interactive program that'll help you build production-ready machine learning systems from the ground up.", 'language': 'en'}, page_content="then, thousands of students have graduated, and I can't wait to meet you in class.Copyright © 2024 Tideily LLCAll rights reserved.")]

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Initialize the text splitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=20)

# Specify the path to your PDF file
loader = PyPDFLoader('./2021-q3-alphabet-10q.pdf')

# Load and split the PDF document
documents = loader.load_and_split(text_splitter)

# Output the documents
documents
# Out:
# [Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 0}, page_content='UNITED STATES\nSECURITIES AND EXCHANGE COMMISSION\nWashington, D.C. 20549\n________________________________________________________________________________________\nFORM 10-Q \n________________________________________________________________________________________\n(Mark One)\n☒ QUARTERLY REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934\nFor the quarterly period ended September 30, 2021\nOR\n☐ TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934\nFor the transition period from _______ to _______\nCommission file number: 001-37580 \n________________________________________________________________________________________\nAlphabet Inc. \n(Exact name of registrant as specified in its charter)\n________________________________________________________________________________________\nDelaware 61-1767919\n(State or other jurisdiction of incorporation or organization) (I.R.S. Employer Identification Number)\n1600 Amphitheatre Parkway'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 0}, page_content="Mountain View, CA 94043\n(Address of principal executive offices, including zip code)\n(650) 253-0000\n(Registrant's telephone number, including area code)\nSecurities registered pursuant to Section 12(b) of the Act:\nTitle of each class Trading Symbol(s) Name of each exchange on which registered\nClass A Common Stock, $0.001 par value GOOGL Nasdaq Stock Market LLC\n(Nasdaq Global Select Market)\nClass C Capital Stock, $0.001 par value GOOG Nasdaq Stock Market LLC\n(Nasdaq Global Select Market)\n________________________________________________________________________________________\nIndicate by check mark whether the registrant: (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities \nExchange Act of 1934 during the preceding 12 months (or for such shorter period that the registrant was required to file such \nreports), and (2) has been subject to such filing requirements for the past 90 days.    Yes  ☒    No  ☐"),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 0}, page_content='Indicate by check mark whether the registrant has submitted electronically every Interactive Data File required to be submitted \npursuant to Rule 405 of Regulation S-T (§232.405 of this chapter) during the preceding 12 months (or for such shorter period \nthat the registrant was required to submit such files).    Yes  ☒    No  ☐\nIndicate by check mark whether the registrant is a large accelerated filer, an accelerated filer, a non-accelerated filer, a smaller \nreporting company, or an emerging growth company. See the definitions of “large accelerated filer,” “accelerated filer,” “smaller \nreporting company,” and "emerging growth company" in Rule 12b-2 of the Exchange Act.\nLarge accelerated filer ☒   Accelerated filer ☐\nNon-accelerated filer ☐ Smaller reporting company ☐\nEmerging growth company ☐\nIf an emerging growth company, indicate by check mark if the registrant has elected not to use the extended transition period for'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 0}, page_content="complying with any new or revised financial accounting standards provided pursuant to Section 13(a) of the Exchange Act.                          \n☐\nIndicate by check mark whether the registrant is a shell company (as defined in Rule 12b-2 of the Exchange Act).  Yes  ☐    No  \n☒\nAs of October 19, 2021, there were 300,809,676 shares of Alphabet’s Class A common stock outstanding, 45,216,540 shares of \nAlphabet's Class B common stock outstanding, and 317,737,778 shares of Alphabet's Class C capital stock outstanding."),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 1}, page_content="Alphabet Inc.\nForm 10-Q\nFor the Quarterly Period Ended September 30, 2021 \nTABLE OF CONTENTS\n  Page No.\nNote About Forward-Looking Statements 3\nPART I. FINANCIAL INFORMATION\nItem 1 Financial Statements 5\nConsolidated Balance Sheets - December 31, 2020 and September 30, 2021 5\nConsolidated Statements of Income - Three and Nine Months Ended September 30, 2020 \nand 2021\n6\nConsolidated Statements of Comprehensive Income - Three and Nine Months Ended \nSeptember 30, 2020 and 2021\n7\nConsolidated Statements of Stockholders' Equity - Three and Nine Months Ended September \n30, 2020 and 2021\n8\nConsolidated Statements of Cash Flows - Nine Months Ended September 30, 2020 and 2021 10\nNotes to Consolidated Financial Statements 11\nItem 2 Management’s Discussion and Analysis of Financial Condition and Results of Operations 33\nItem 3 Quantitative and Qualitative Disclosures About Market Risk 47\nItem 4 Controls and Procedures 47\nPART II. OTHER INFORMATION\nItem 1 Legal Proceedings 48"),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 1}, page_content='Item 1A Risk Factors 48\nItem 2 Unregistered Sales of Equity Securities and Use of Proceeds 49\nItem 6 Exhibits 50\nSignature 51\nTable of Contents Alphabet Inc.\n2'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 2}, page_content='Note About Forward-Looking Statements\nThis Quarterly Report on Form 10-Q contains forward-looking statements within the meaning of the Private \nSecurities Litigation Reform Act of 1995. These statements include, among other things, statements regarding:\n• the ongoing effect of the novel coronavirus pandemic ("COVID-19"), including its macroeconomic effects on \nour business, operations, and financial results; and the effect of governmental lockdowns, restrictions and \nnew regulations on our operations and processes;\n• the growth of our business and revenues and our expectations about the factors that influence our success \nand trends in our business, including the size and timing of the expected return on our continuing \ninvestments in our Google Cloud segment;\n• fluctuations in our revenue growth rate and operating margin and various factors contributing to such \nfluctuations;\n• our expectation that the shift from an offline to online world will continue to benefit our business;'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 2}, page_content='• our expectation that the portion of our revenues that we derive from non-advertising revenues will continue \nto increase and may affect our margins;\n• our expectation that our traffic acquisition costs ("TAC") and the associated TAC rate will fluctuate, which \ncould affect our overall margins;\n• our expectation that our monetization trends will fluctuate, which could affect our revenues and margins;\n• fluctuations in our revenue growth, as well as the change in paid clicks and cost-per-click and the change in \nimpressions and cost-per-impression, and various factors contributing to such fluctuations;\n• our expectation that we will continue to periodically review, refine, and update our methodologies for \nmonitoring, gathering, and counting the number of paid clicks and impressions;\n• our expectation that our results will be affected by our performance in international markets as users in \ndeveloping economies increasingly come online;'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 2}, page_content='• our expectation that our foreign exchange risk management program will not fully offset our net exposure to \nfluctuations in foreign currency exchange rates;\n• the expected variability of gains and losses related to hedging activities under our foreign exchange risk \nmanagement program;\n• the amount and timing of revenue recognition from customer contracts with commitments for performance \nobligations, including our estimate of the remaining amount of commitments and when we expect to \nrecognize revenue;\n• fluctuations in our capital expenditures;\n• our plans to continue to invest in new businesses, products, services and technologies, systems, land and \nbuildings for data centers and offices, and infrastructure, as well as to continue to invest in acquisitions;\n• our pace of hiring and our plans to provide competitive compensation programs;\n• our expectation that our cost of revenues, research and development ("R&D") expenses, sales and'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 2}, page_content='marketing expenses, and general and administrative expenses may increase in amount and/or may \nincrease as a percentage of revenues and may be affected by a number of factors;\n• estimates of our future compensation expenses;\n• our expectation that our other income (expense), net ("OI&E"), will fluctuate in the future, as it is largely \ndriven by market dynamics;\n• fluctuations in our effective tax rate;\n• seasonal fluctuations in internet usage and advertiser expenditures, underlying business trends such as \ntraditional retail seasonality (including developments and volatility arising from COVID-19), which are likely \nto cause fluctuations in our quarterly results;\n• the sufficiency of our sources of funding;\n• our potential exposure in connection with new and pending investigations, proceedings, and other \ncontingencies;\nTable of Contents Alphabet Inc.\n3'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 3}, page_content='• the sufficiency and timing of our proposed remedies in response to decisions from the European \nCommission ("EC") and other regulators and governmental entities;\n• our expectations regarding the timing, design and implementation of our new global enterprise resource \nplanning ("ERP") system;\n• the expected timing, amount, and impact of Alphabet Inc.\'s share repurchases;\n• our long-term sustainability and diversity goals;\n• our expectation that the change in the estimated useful life of servers and certain network equipment will \nhave a favorable, yet declining, effect on our 2021 operating results;\nas well as other statements regarding our future operations, financial condition and prospects, and business \nstrategies. Forward-looking statements may appear throughout this report and other documents we file with the \nSecurities and Exchange Commission ("SEC"), including without limitation, the following sections: Part I, Item 2,'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 3}, page_content='"Management\'s Discussion and Analysis of Financial Condition and Results of Operations" in this Quarterly Report \non Form 10-Q and Part I, Item 1A, “Risk Factors” in our Annual Report on Form 10-K for the fiscal year ended \nDecember 31, 2020, as updated in this Quarterly Report on Form 10-Q . Forward-looking statements generally can \nbe identified by words such as "anticipates," "believes," "estimates," "expects," "intends," "plans," "predicts," \n"projects," "will be," "will continue," "may," "could," "will likely result," and similar expressions. These forward-looking \nstatements are based on current expectations and assumptions that are subject to risks and uncertainties, which \ncould cause our actual results to differ materially from those reflected in the forward-looking statements. Factors \nthat could cause or contribute to such differences include, but are not limited to, those discussed in this Quarterly'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 3}, page_content='Report on Form 10-Q, and in particular, the risks discussed in Part I, Item 1A, "Risk Factors" in our Annual Report \non Form 10-K for the fiscal year ended December 31, 2020, as updated in this Quarterly Report on Form 10-Q, and \nthose discussed in other documents we file with the SEC. We undertake no obligation to revise or publicly release \nthe results of any revision to these forward-looking statements, except as required by law. Given these risks and \nuncertainties, readers are cautioned not to place undue reliance on such forward-looking statements.\n As used herein, "Alphabet," "the company," "we," "us," "our," and similar terms include Alphabet Inc. and its \nsubsidiaries, unless the context indicates otherwise.\n "Alphabet," "Google," and other trademarks of ours appearing in this report are our property. This report \ncontains additional trade names and trademarks of other companies. We do not intend our use or display of other'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 3}, page_content="companies' trade names or trademarks to imply an endorsement or sponsorship of us by such companies, or any \nrelationship with any of these companies.\nTable of Contents Alphabet Inc.\n4"),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 4}, page_content='PART I. FINANCIAL INFORMATION\nITEM 1. FINANCIAL STATEMENTS\nAlphabet Inc.\nCONSOLIDATED BALANCE SHEETS\n(in millions, except share amounts which are reflected in thousands, and par value per share amounts)\nAs of \nDecember 31, 2020\nAs of\nSeptember 30, 2021\n(unaudited)\nAssets\nCurrent assets:\nCash and cash equivalents $ 26,465 $ 23,719 \nMarketable securities  110,229  118,284 \nTotal cash, cash equivalents, and marketable securities  136,694  142,003 \nAccounts receivable, net  30,930  34,047 \nIncome taxes receivable, net  454  753 \nInventory  728  1,278 \nOther current assets  5,490  6,029 \nTotal current assets  174,296  184,110 \nNon-marketable investments  20,703  26,101 \nDeferred income taxes  1,084  1,195 \nProperty and equipment, net  84,749  94,631 \nOperating lease assets  12,211  12,918 \nIntangible assets, net  1,445  1,549 \nGoodwill  21,175  22,623 \nOther non-current assets  3,953  4,276 \nTotal assets $ 319,616 $ 347,403 \nLiabilities and Stockholders’ Equity\nCurrent liabilities:'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 4}, page_content='Accounts payable $ 5,589 $ 4,616 \nAccrued compensation and benefits  11,086  12,170 \nAccrued expenses and other current liabilities  28,631  30,113 \nAccrued revenue share  7,500  7,745 \nDeferred revenue  2,543  2,968 \nIncome taxes payable, net  1,485  4,170 \nTotal current liabilities  56,834  61,782 \nLong-term debt  13,932  14,288 \nDeferred revenue, non-current  481  510 \nIncome taxes payable, non-current  8,849  8,984 \nDeferred income taxes  3,561  3,551 \nOperating lease liabilities  11,146  11,471 \nOther long-term liabilities  2,269  2,250 \nTotal liabilities  97,072  102,836 \nContingencies (Note 9)\nStockholders’ equity:\nConvertible preferred stock, $0.001 par value per share, 100,000 shares \nauthorized; no shares issued and outstanding  0  0 \nClass A and Class B common stock, and Class C capital stock and \nadditional paid-in capital, $0.001 par value per share: 15,000,000 shares \nauthorized (Class A 9,000,000, Class B 3,000,000, Class C 3,000,000);'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 4}, page_content='675,222 (Class A 300,730, Class B 45,843, Class C 328,649) and \n664,682 (Class A 300,801, Class B 45,261, Class C 318,620) shares \nissued and outstanding\n 58,510  61,193 \nAccumulated other comprehensive income (loss)  633  (408) \nRetained earnings  163,401  183,782 \nTotal stockholders’ equity  222,544  244,567 \nTotal liabilities and stockholders’ equity $ 319,616 $ 347,403 \nSee accompanying notes.\nTable of Contents Alphabet Inc.\n5'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 5}, page_content='Alphabet Inc.\nCONSOLIDATED STATEMENTS OF INCOME\n(in millions, except per share amounts; unaudited)\nThree Months Ended Nine Months Ended\nSeptember 30, September 30,\n2020 2021 2020 2021\nRevenues $ 46,173 $ 65,118 $ 125,629 $ 182,312 \nCosts and expenses:\nCost of revenues  21,117  27,621  58,652  77,951 \nResearch and development  6,856  7,694  20,551  22,854 \nSales and marketing  4,231  5,516  12,632  15,308 \nGeneral and administrative  2,756  3,256  8,221  9,370 \nTotal costs and expenses  34,960  44,087  100,056  125,483 \nIncome from operations  11,213  21,031  25,573  56,829 \nOther income (expense), net  2,146  2,033  3,820  9,503 \nIncome before income taxes  13,359  23,064  29,393  66,332 \nProvision for income taxes  2,112  4,128  4,351  10,941 \nNet income $ 11,247 $ 18,936 $ 25,042 $ 55,391 \nBasic net income per share of Class A and B \ncommon stock and Class C capital stock $ 16.55 $ 28.44 $ 36.69 $ 82.76 \nDiluted net income per share of Class A and B'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 5}, page_content='common stock and Class C capital stock $ 16.40 $ 27.99 $ 36.38 $ 81.53 \nSee accompanying notes.\nTable of Contents Alphabet Inc.\n6'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 6}, page_content='Alphabet Inc.\nCONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME\n(in millions; unaudited)\nThree Months Ended Nine Months Ended\n September 30, September 30,\n 2020 2021 2020 2021\nNet income $ 11,247 $ 18,936 $ 25,042 $ 55,391 \nOther comprehensive income (loss):\nChange in foreign currency translation adjustment  459  (614)  193  (671) \nAvailable-for-sale investments:\nChange in net unrealized gains (losses)  (19)  (159)  1,346  (699) \nLess: reclassification adjustment for net (gains) losses \nincluded in net income  (73)  (57)  (391)  (121) \nNet change, net of income tax benefit (expense) of $27, \n$63, $(274) and $235  (92)  (216)  955  (820) \nCash flow hedges:\nChange in net unrealized gains (losses)  (48)  292  244  429 \nLess: reclassification adjustment for net (gains) losses \nincluded in net income  23  (60)  (114)  21 \nNet change, net of income tax benefit (expense) of $8, \n$(54), $(38) and $(89)  (25)  232  130  450 \nOther comprehensive income (loss)  342  (598)  1,278  (1,041)'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 6}, page_content='Comprehensive income $ 11,589 $ 18,338 $ 26,320 $ 54,350 \nSee accompanying notes.\nTable of Contents Alphabet Inc.\n7'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 7}, page_content='Alphabet Inc.\nCONSOLIDATED STATEMENTS OF STOCKHOLDERS’ EQUITY\n(In millions, except share amounts which are reflected in thousands; unaudited)\n Three Months Ended September 30, 2020\n \nClass A and Class B Common \nStock, Class C Capital Stock \nand Additional Paid-In Capital\nAccumulated\nOther\nComprehensive\nIncome (Loss)\nRetained\nEarnings\nTotal\nStockholders’\nEquity Shares    Amount    \nBalance as of June 30, 2020  681,215 $ 55,937 $ (296) $ 151,681 $ 207,322 \nCommon and capital stock issued  1,669  15  0  0  15 \nStock-based compensation expense  0  3,230  0  0  3,230 \nTax withholding related to vesting of \nrestricted stock units and other  0  (1,339)  0  0  (1,339) \nRepurchases of capital stock  (5,160)  (536)  0  (7,361)  (7,897) \nSale of interest in consolidated entities  0  0  0  0  0 \nNet income  0  0  0  11,247  11,247 \nOther comprehensive income (loss)  0  0  342  0  342 \nBalance as of September 30, 2020  677,724 $ 57,307 $ 46 $ 155,567 $ 212,920 \n Nine Months Ended September 30, 2020'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 7}, page_content='Class A and Class B Common \nStock, Class C Capital Stock \nand Additional Paid-In Capital\nAccumulated\nOther\nComprehensive\nIncome (Loss)\nRetained\nEarnings\nTotal\nStockholders’\nEquity Shares    Amount    \nBalance as of December 31, 2019  688,335 $ 50,552 $ (1,232) $ 152,122 $ 201,442 \nCommon and capital stock issued  6,185  158  0  0  158 \nStock-based compensation expense  0  9,865  0  0  9,865 \nTax withholding related to vesting of \nrestricted stock units and other  0  (4,076)  0  0  (4,076) \nRepurchases of capital stock  (16,796)  (1,648)  0  (21,597)  (23,245) \nSale of interest in consolidated entities  0  2,456  0  0  2,456 \nNet income  0  0  0  25,042  25,042 \nOther comprehensive income (loss)  0  0  1,278  0  1,278 \nBalance as of September 30, 2020  677,724 $ 57,307 $ 46 $ 155,567 $ 212,920 \nTable of Contents Alphabet Inc.\n8'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 8}, page_content='Three Months Ended September 30, 2021\n \nClass A and Class B Common \nStock, Class C Capital Stock \nand Additional Paid-In Capital\nAccumulated\nOther\nComprehensive\nIncome (Loss)\nRetained\nEarnings\nTotal\nStockholders’\nEquity Shares    Amount    \nBalance as of June 30, 2021  667,637 $ 60,436 $ 190 $ 176,939 $ 237,565 \nCommon and capital stock issued  1,626  1  0  0  1 \nStock-based compensation expense  0  3,914  0  0  3,914 \nTax withholding related to vesting of \nrestricted stock units and other  0  (2,641)  0  0  (2,641) \nRepurchases of common and capital \nstock  (4,581)  (517)  0  (12,093)  (12,610) \nSale of interest in consolidated entities  0  0  0  0  0 \nNet income  0  0  0  18,936  18,936 \nOther comprehensive income (loss)  0  0  (598)  0  (598) \nBalance as of September 30, 2021  664,682 $ 61,193 $ (408) $ 183,782 $ 244,567 \n Nine Months Ended September 30, 2021\n \nClass A and Class B Common \nStock, Class C Capital Stock \nand Additional Paid-In Capital\nAccumulated\nOther\nComprehensive'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 8}, page_content='Other\nComprehensive\nIncome (Loss)\nRetained\nEarnings\nTotal\nStockholders’\nEquity Shares    Amount    \nBalance as of December 31, 2020  675,222 $ 58,510 $ 633 $ 163,401 $ 222,544 \nCommon and capital stock issued  5,114  8  0  0  8 \nStock-based compensation expense  0  11,546  0  0  11,546 \nTax withholding related to vesting of \nrestricted stock units and other  0  (7,390)  0  0  (7,390) \nRepurchases of common and capital \nstock  (15,654)  (1,791)  0  (35,010)  (36,801) \nSale of interest in consolidated entities  0  310  0  0  310 \nNet income  0  0  0  55,391  55,391 \nOther comprehensive income (loss)  0  0  (1,041)  0  (1,041) \nBalance as of September 30, 2021  664,682 $ 61,193 $ (408) $ 183,782 $ 244,567 \nSee accompanying notes.\nTable of Contents Alphabet Inc.\n9'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 9}, page_content='Alphabet Inc.\nCONSOLIDATED STATEMENTS OF CASH FLOWS\n(in millions; unaudited)\nNine Months Ended\nSeptember 30,\n2020 2021\nOperating activities\nNet income $ 25,042 $ 55,391 \nAdjustments:\nDepreciation and impairment of property and equipment  9,366  8,340 \nAmortization and impairment of intangible assets  606  662 \nStock-based compensation expense  9,768  11,422 \nDeferred income taxes  (280)  192 \nGain on debt and equity securities, net  (3,055)  (9,792) \nOther  875  (199) \nChanges in assets and liabilities, net of effects of acquisitions:\nAccounts receivable  (1,079)  (3,276) \nIncome taxes, net  469  2,744 \nOther assets  (592)  (1,447) \nAccounts payable  (269)  (874) \nAccrued expenses and other liabilities  891  2,763 \nAccrued revenue share  277  386 \nDeferred revenue  428  406 \nNet cash provided by operating activities  42,447  66,718 \nInvesting activities\nPurchases of property and equipment  (16,802)  (18,257) \nPurchases of marketable securities  (104,932)  (95,106)'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 9}, page_content='Maturities and sales of marketable securities  97,751  92,126 \nPurchases of non-marketable investments  (1,864)  (2,068) \nMaturities and sales of non-marketable investments  598  590 \nAcquisitions, net of cash acquired, and purchases of intangible assets  (368)  (2,233) \nOther investing activities  125  441 \nNet cash used in investing activities  (25,492)  (24,507) \nFinancing activities\nNet payments related to stock-based award activities  (4,073)  (7,239) \nRepurchases of common and capital stock  (23,245)  (36,801) \nProceeds from issuance of debt, net of costs  11,761  13,949 \nRepayments of debt  (2,043)  (15,070) \nProceeds from sale of interest in consolidated entities, net  2,462  310 \nNet cash used in financing activities  (15,138)  (44,851) \nEffect of exchange rate changes on cash and cash equivalents  (186)  (106) \nNet increase (decrease) in cash and cash equivalents  1,631  (2,746) \nCash and cash equivalents at beginning of period  18,498  26,465'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 9}, page_content='Cash and cash equivalents at end of period $ 20,129 $ 23,719 \nSee accompanying notes.\nTable of Contents Alphabet Inc.\n10'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 10}, page_content='Alphabet Inc.\nNOTES TO CONSOLIDATED FINANCIAL STATEMENTS\n(Unaudited)\nNote 1.    Nature of Operations and Summary of Significant Accounting Policies \nNature of Operations\nGoogle was incorporated in California in September 1998 and re-incorporated in the State of Delaware in \nAugust 2003. In 2015, we implemented a holding company reorganization, and as a result, Alphabet became the \nsuccessor issuer to Google.\nWe generate revenues by delivering relevant, cost-effective online advertising, cloud-based solutions that \nprovide customers with platforms, collaboration tools and services, and sales of other products and services, such \nas apps and in-app purchases, digital content and subscriptions for digital content, and hardware.\nBasis of Consolidation\nThe consolidated financial statements of Alphabet include the accounts of Alphabet and entities consolidated \nunder the variable interest and voting models. All intercompany balances and transactions have been eliminated.'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 10}, page_content='Unaudited Interim Financial Information\nThe Consolidated Balance Sheet as of September 30, 2021 , the Consolidated Statements of Income for the \nthree and nine months ended September 30, 2020  and 2021, the Consolidated Statements of Comprehensive \nIncome for the three and nine months ended September 30, 2020  and 2021, the Consolidated Statements of \nStockholders\' Equity for the three and nine months ended September 30, 2020  and 2021 and the Consolidated \nStatements of Cash Flows for the nine months ended September 30, 2020  and 2021 are unaudited. These \nunaudited interim consolidated financial statements have been prepared in accordance with generally accepted \naccounting principles in the United States ("GAAP"). In our opinion, the unaudited interim consolidated financial \nstatements include all adjustments of a normal recurring nature necessary for the fair presentation of our financial'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 10}, page_content='position as of September 30, 2021 , our results of operations for the three and nine months ended September 30, \n2020 and 2021, and our cash flows for the nine months ended September 30, 2020  and 2021. The results of \noperations for the three and nine months ended September 30, 2021  are not necessarily indicative of the results to \nbe expected for the year ending December 31, 2021.\nThese unaudited interim consolidated financial statements should be read in conjunction with the consolidated \nfinancial statements and the related notes included in our Annual Report on Form 10-K for the fiscal year ended \nDecember 31, 2020 filed with the SEC.\nUse of Estimates\nPreparation of consolidated financial statements in conformity with GAAP requires us to make estimates and \nassumptions that affect the amounts reported and disclosed in the financial statements and the accompanying \nnotes. Actual results could differ materially from these estimates. On an ongoing basis, we evaluate our estimates,'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 10}, page_content='including those related to the allowance for credit losses, fair values of financial instruments, intangible assets and \ngoodwill, useful lives of intangible assets and property and equipment, income taxes, and contingent liabilities, \namong others. We base our estimates on assumptions, both historical and forward looking, that are believed to be \nreasonable, the results of which form the basis for making judgments about the carrying values of assets and \nliabilities.\nThe allowance for credit losses on accounts receivable was $789 million and $567 million as of December 31, \n2020 and September 30, 2021, respectively.\nChange in Accounting Estimate\nIn January 2021, we completed an assessment of the useful lives of our servers and network equipment and \nadjusted the estimated useful life of our servers from three years  to four years  and the estimated useful life of \ncertain network equipment from three years  to five years . This change in accounting estimate was effective'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 10}, page_content='beginning in fiscal year 2021. Based on the carrying value of servers and certain network equipment as of \nDecember 31, 2020 , and those acquired during the nine months ended September 30, 2021 , the effect of this \nchange in estimate was a reduction in depreciation expense of $591 million and $2.1 billion and an increase in net \nincome of $460 million and $1.7 billion, or $0.69 and $2.50 per basic share and $0.68 and $2.46 per diluted share, \nfor the three and nine months ended September 30, 2021, respectively.\nTable of Contents Alphabet Inc.\n11'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 11}, page_content='Prior Period Reclassifications\nCertain amounts in prior periods have been reclassified to conform with current period presentation.\nNote 2.    Revenues \nRevenue Recognition\nThe following table presents our revenues disaggregated by type (in millions). \nThree Months Ended Nine Months Ended\nSeptember 30, September 30,\n2020 2021 2020 2021\nGoogle Search & other $ 26,338 $ 37,926 $ 72,159 $ 105,650 \nYouTube ads  5,037  7,205  12,887  20,212 \nGoogle Network  5,720  7,999  15,679  22,396 \nGoogle advertising  37,095  53,130  100,725  148,258 \nGoogle other  5,478  6,754  15,037  19,871 \nGoogle Services total  42,573  59,884  115,762  168,129 \nGoogle Cloud  3,444  4,990  9,228  13,665 \nOther Bets  178  182  461  572 \nHedging gains (losses)  (22)  62  178  (54) \nTotal revenues $ 46,173 $ 65,118 $ 125,629 $ 182,312 \nThe following table presents our revenues disaggregated by geography, based on the addresses of our \ncustomers (in millions):\n Three Months Ended Nine Months Ended'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 11}, page_content='September 30, September 30,\n 2020 2021 2020 2021\nUnited States $ 21,442  47 % $ 29,824  46 % $ 58,311  47 % $ 83,064  46 %\nEMEA(1)  13,924  30  19,839  30  38,132  30  55,954  31 \nAPAC(1)  8,458  18  11,705  18  22,641  18  33,391  18 \nOther Americas(1)  2,371  5  3,688  6  6,367  5  9,957  5 \nHedging gains (losses)  (22)  0  62  0  178  0  (54)  0 \nTotal revenues $ 46,173  100 % $ 65,118  100 % $ 125,629  100 % $ 182,312  100 %\n(1) Regions represent Europe, the Middle East, and Africa ("EMEA"); Asia-Pacific ("APAC"); and Canada and Latin America \n("Other Americas").\nDeferred Revenues and Remaining Performance Obligations\nWe record deferred revenues when cash payments are received or due in advance of our performance, \nincluding amounts which are refundable. Deferred revenues primarily relate to Google Cloud and Google other. Our \ntotal deferred revenue was $3.0 billion  and $3.5 billion  as of December 31, 2020  and September 30, 2021 ,'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 11}, page_content='respectively. Of the total deferred revenue as of December 31, 2020 , $2.1 billion  was recognized as revenues \nduring the nine months ended September 30, 2021.\nAdditionally, we have performance obligations associated with commitments in customer contracts, primarily \nrelated to Google Cloud, for future services that have not yet been recognized as revenues, also referred to as \nremaining performance obligations. Remaining performance obligations include related deferred revenue currently \nrecorded as well as amounts that will be invoiced in future periods, and excludes (i) contracts with an original \nexpected term of one year or less, (ii) cancellable contracts, and (iii) contracts for which we recognize revenue at \nthe amount to which we have the right to invoice for services performed. As of September 30, 2021, the amount not \nyet recognized as revenues from these commitments was  $37.1 billion. We expect to recognize approximately half'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 11}, page_content='over the next  24 months with the remaining thereafte r. However, the amount and timing of revenue recognition is \nlargely driven by when the customer utilizes the services and our ability to deliver in accordance with relevant \ncontract terms, which could affect our estimate of the remaining performance obligations and when we expect to \nrecognize such as revenues.  \nTable of Contents Alphabet Inc.\n12'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 12}, page_content='Note 3.    Financial Instruments\nDebt Securities\nWe classify our marketable debt securities, which are accounted for as available-for-sale, within Level 2 in the \nfair value hierarchy because we use quoted market prices to the extent available or alternative pricing sources and \nmodels utilizing market observable inputs to determine fair value.\nFor certain marketable debt securities, we have elected the fair value option for which changes in fair value \nare recorded in other income (expense), net. The fair value option was elected for these securities to align with the \nunrealized gains and losses from related derivative contracts. Unrealized net gains related to debt securities still \nheld where we have elected the fair value option were $87 million and $22 million as of December 31, 2020 and \nSeptember 30, 2021, respectively. As of December 31, 2020 and September 30, 2021, the fair value of these debt \nsecurities was $2.0 billion and $3.0 billion, respectively.'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 12}, page_content='The following tables summarize our debt securities, for which we did not elect the fair value option, by \nsignificant investment categories (in millions):\n As of December 31, 2020\n \nAdjusted\nCost\nGross\nUnrealized\nGains\nGross\nUnrealized\nLosses\nFair\nValue\nCash and \nCash\nEquivalents\nMarketable\nSecurities\nLevel 2:\nTime deposits(1) $ 3,564 $ 0 $ 0 $ 3,564 $ 3,564 $ 0 \nGovernment bonds  55,156  793  (9)  55,940  2,527  53,413 \nCorporate debt securities  31,521  704  (2)  32,223  8  32,215 \nMortgage-backed and asset-backed \nsecurities  16,767  364  (7)  17,124  0  17,124 \nTotal $ 107,008 $ 1,861 $ (18) $ 108,851 $ 6,099 $ 102,752 \n As of September 30, 2021\n \nAdjusted\nCost\nGross\nUnrealized\nGains\nGross\nUnrealized\nLosses\nFair\nValue\nCash and \nCash\nEquivalents\nMarketable\nSecurities\nLevel 2:\nTime deposits(1) $ 5,277 $ 0 $ 0 $ 5,277 $ 5,277 $ 0 \nGovernment bonds  53,793  371  (93)  54,071  3  54,068 \nCorporate debt securities  35,156  362  (51)  35,467  0  35,467 \nMortgage-backed and asset-backed'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 12}, page_content='securities  18,327  172  (44)  18,455  0  18,455 \nTotal $ 112,553 $ 905 $ (188) $ 113,270 $ 5,280 $ 107,990 \n(1) The majority of our time deposits are domestic deposits.\nWe determine realized gains or losses on the sale or extinguishment of debt securities on a specific \nidentification method. We recognized gross realized gains of $127 million  and $109 million  for the three months \nended September 30, 2020  and 2021, respectively, and $690 million and $360 million for the nine months ended \nSeptember 30, 2020 and 2021, respectively. We recognized gross realized losses of $8 million and $29 million for \nthe three months ended September 30, 2020  and 2021, respectively, and $135 million and $180 million for the nine \nmonths ended September 30, 2020  and 2021, respectively. We reflect these gains and losses as a component of \nother income (expense), net.\nTable of Contents Alphabet Inc.\n13'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 13}, page_content='The following table summarizes the estimated fair value of our investments in marketable debt securities by \nstated contractual maturity dates (in millions):\nAs of\nSeptember 30, 2021\nDue in 1 year or less $ 19,074 \nDue in 1 year through 5 years  73,675 \nDue in 5 years through 10 years  4,207 \nDue after 10 years  13,993 \nTotal $ 110,949 \nThe following tables present fair values and gross unrealized losses recorded to AOCI, aggregated by \ninvestment category and the length of time that individual securities have been in a  continuous loss position (in \nmillions):\n As of December 31, 2020\n Less than 12 Months 12 Months or Greater Total\n Fair Value\nUnrealized\nLoss Fair Value\nUnrealized\nLoss Fair Value\nUnrealized\nLoss\nGovernment bonds $ 5,516 $ (9) $ 3 $ 0 $ 5,519 $ (9) \nCorporate debt securities  1,999  (1)  0  0  1,999  (1) \nMortgage-backed and asset-backed \nsecurities  929  (5)  242  (2)  1,171  (7) \nTotal $ 8,444 $ (15) $ 245 $ (2) $ 8,689 $ (17) \n As of September 30, 2021'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 13}, page_content='Less than 12 Months 12 Months or Greater Total\n Fair Value\nUnrealized\nLoss Fair Value\nUnrealized\nLoss Fair Value\nUnrealized\nLoss\nGovernment bonds $ 28,507 $ (92) $ 54 $ (1) $ 28,561 $ (93) \nCorporate debt securities  11,293  (19)  245  (2)  11,538  (21) \nMortgage-backed and asset-backed \nsecurities  8,371  (41)  188  (3)  8,559  (44) \nTotal $ 48,171 $ (152) $ 487 $ (6) $ 48,658 $ (158) \nDuring the three and nine months ended September 30, 2020  and 2021, we did not recognize any significant \ncredit losses and the ending allowance balances for credit losses were immaterial  as of December 31, 2020  and \nSeptember 30, 2021.\nEquity Investments\nThe following discusses our marketable equity securities, non-marketable equity securities, gains and losses \non marketable and non-marketable equity securities, as well as our equity securities accounted for under the equity \nmethod.\nOur marketable equity securities are publicly traded stocks or funds measured at fair value and classified'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 13}, page_content='within Level 1 and 2 in the fair value hierarchy because we use quoted prices for identical assets in active markets \nor inputs that are based upon quoted prices for similar instruments in active markets.\nOur non-marketable equity securities are investments in privately held companies without readily determinable \nmarket values. The carrying value of our non-marketable equity securities is adjusted to fair value upon observable \ntransactions for identical or similar investments of the same issuer or impairment (referred to as the measurement \nalternative). Non-marketable equity securities that have been remeasured during the period based on observable \ntransactions are classified within Level 2 or Level 3 in the fair value hierarchy because we estimate the value based \non valuation methods which may include a combination of the observable transaction price at the transaction date'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 13}, page_content='and other unobservable inputs including  volatility, rights, and obligations of the securities we hold.  The fair value of \nnon-marketable equity securities that have been remeasured due to impairment are classified within Level 3.\nTable of Contents Alphabet Inc.\n14'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 14}, page_content='Gains and losses on marketable and non-marketable equity securities\nGains and losses reflected in other income (expense), net, for our marketable and non-marketable equity \nsecurities are summarized below (in millions):\nThree Months Ended Nine Months Ended\nSeptember 30, September 30,\n2020 2021 2020 2021\nNet gain (loss) on equity securities sold during the period $ (5) $ (36) $ 426 $ 545 \nNet unrealized gain (loss) on equity securities held as of \nthe end of the period  1,904  2,157  2,114  9,185 \nTotal gain (loss) recognized in other income \n(expense), net $ 1,899 $ 2,121 $ 2,540 $ 9,730 \nIn the table above, net gain (loss) on equity securities sold during the period reflects the difference between the \nsale proceeds and the carrying value of the equity securities at the beginning of the period or the purchase date, if \nlater. \nCumulative net gains (losses) on equity securities sold during the period, which is summarized in the following'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 14}, page_content='table (in millions), represents the total net gains (losses) recognized after the initial purchase date of the equity \nsecurity. While these net gains may have been reflected in periods prior to the period of sale, we believe they are \nimportant supplemental information as they reflect the economic realized net gains on the securities sold during the \nperiod. Cumulative net gains are calculated as the difference between the sale price and the initial purchase price \nfor the equity security sold during the period.\nEquity Securities Sold\nThree Months Ended Nine Months Ended\nSeptember 30, September 30,\n 2020 2021 2020 2021\nTotal sale price $ 1,389 $ 1,199 $ 2,888 $ 4,553 \nTotal initial cost  1,146  188  1,831  955 \nCumulative net gains(1) $ 243 $ 1,011 $ 1,057 $ 3,598 \n(1) Cumulative net gains excludes cumulative losses of $684 million resulting from our equity derivatives, which hedged the'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 14}, page_content='changes in fair value of certain marketable equity securities sold during the second quarter of 2021 . The associated \nderivative liabilities arising from these losses were settled against our holdings of the underlying equity securities. \nCarrying value of marketable and non-marketable equity securities\nThe carrying value is measured as the total initial cost plus the cumulative net gain (loss). The carrying values \nfor our marketable and non-marketable equity securities are summarized below (in millions):\nAs of December 31, 2020\nMarketable \nSecurities\nNon-Marketable \nSecurities Total\nTotal initial cost $ 2,227 $ 14,616 $ 16,843 \nCumulative net gain (loss)(1)  3,631  4,277  7,908 \nCarrying value(2) $ 5,858 $ 18,893 $ 24,751 \n(1) Non-marketable equity securities cumulative net gain (loss) is comprised of $6.1 billion unrealized gains and $1.9 billion \nunrealized losses (including impairment).'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 14}, page_content='(2) The long-term portion of marketable equity securities of $429 million is included within other non-current assets.\nAs of September 30, 2021\nMarketable \nSecurities(2)\nNon-Marketable \nSecurities Total\nTotal initial cost $ 2,823 $ 14,944 $ 17,767 \nCumulative net gain (loss)(1)  4,954  9,194  14,148 \nCarrying value(2) $ 7,777 $ 24,138 $ 31,915 \n(1) Non-marketable equity securities cumulative net gain (loss) is comprised of $10.9 billion unrealized gains and $1.7 billion \nunrealized losses (including impairment).\n(2) The long-term portion of marketable equity securities of $443 million is included within other non-current assets.\nTable of Contents Alphabet Inc.\n15'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 15}, page_content='Marketable equity securities\nThe following table summarizes marketable equity securities measured at fair value by significant investment \ncategories (in millions):\n As of December 31, 2020 As of September 30, 2021\n \nCash and \nCash \nEquivalents\nMarketable\nSecurities\nCash and \nCash \nEquivalents\nMarketable\nSecurities\nLevel 1:\nMoney market funds $ 12,210 $ 0 $ 10,732 $ 0 \nMarketable equity securities(1)(2)  0  5,470  0  7,430 \n 12,210  5,470  10,732  7,430 \nLevel 2:\nMutual funds  0  388  0  347 \nTotal $ 12,210 $ 5,858 $ 10,732 $ 7,777 \n(1) The balance as of December 31, 2020  and September 30, 2021  includes investments that were reclassified from non-\nmarketable equity securities following the commencement of public market trading of the issuers or acquisition by public \nentities (certain of which are subject to short-term lock-up restrictions). \n(2) As of December 31, 2020  and September 30, 2021  the long-term portion of marketable equity securities of $429 million'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 15}, page_content='and $443 million, respectively, is included within other non-current assets.\nNon-marketable equity securities\nThe following is a summary of unrealized gains and losses recorded in other income (expense), net, and \nincluded as adjustments to the carrying value of non-marketable equity securities (in millions):\nThree Months Ended Nine Months Ended\nSeptember 30, September 30,\n2020 2021 2020 2021\nUnrealized gains $ 1,225 $ 1,260 $ 1,770 $ 6,245 \nUnrealized losses (including impairment)  (27)  (37)  (1,413)  (98) \nTotal unrealized gain (loss) for non-marketable equity \nsecurities $ 1,198 $ 1,223 $ 357 $ 6,147 \nDuring the three months ended September 30, 2021 , included in the $24.1 billion of non-marketable equity \nsecurities, $2.5 billion were measured at fair value resulting in a net unrealized gain of $1.2 billion.\nEquity securities accounted for under the Equity Method\nAs of December 31, 2020  and September 30, 2021 , equity securities accounted for under the equity method'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 15}, page_content='had a carrying value of approximately $ 1.4 billion  and $1.5 billion , respectively. Our share of gains and losses \nincluding impairment are included as a component of other income (expense), net, in the Consolidated Statements \nof Income. See Note 6 for further details on other income (expense), net.\nDerivative Financial Instruments\nWe enter into derivative instruments to manage risks relating to our ongoing business operations. The primary \nrisk managed with derivative instruments is foreign exchange risk. We use foreign currency contracts to reduce the \nrisk that our cash flows, earnings, and investment in foreign subsidiaries will be adversely affected by foreign \ncurrency exchange rate fluctuations. We also enter into derivative instruments to partially offset our exposure to \nother risks and enhance investment returns.\nWe recognize derivative instruments as either assets or liabilities in the Consolidated Balance Sheets at fair'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 15}, page_content='value and classify the derivatives primarily within Level 2 in the fair value hierarchy. We present our collar contracts \n(an option strategy comprised of a combination of purchased and written options) at net fair values where both the \npurchased and written options are with the same counterparty. For other derivative contracts, we present at gross \nfair values. We primarily record changes in the fair value in the Consolidated Statements of Income as either other \nincome (expense), net, or revenues, or in the Consolidated Balance Sheets in AOCI, as discussed below.\nWe enter into master netting arrangements, which reduce credit risk by permitting net settlement of \ntransactions with the same counterparty. Further, we enter into collateral security arrangements that provide for \ncollateral to be received or pledged when the net fair value of certain financial instruments fluctuates from \nTable of Contents Alphabet Inc.\n16'),
# ...
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 45}, page_content='During the nine months ended September 30, 2020  and 2021, we spent $16.8 billion  and $18.3 billion  on \ncapital expenditures and recognized total operating lease assets  of $2.2 billion and $2.2 billion, respectively. As of \nSeptember 30, 2021 , the amount of total future lease payments under operating leases, which had a weighted \naverage remaining lease term of 8 years, was $15.5 billion. As of September 30, 2021, we have entered into leases \nthat have not yet commenced with future lease payments of $6.3 billion, excluding purchase options , that are not \nyet recorded on our Consolidated Balance Sheets. These leases will commence between 2021 and 2026 with non-\ncancelable lease terms of 1 to 25 years.\nFor the nine months ended September 30, 2020  and 2021, our depreciation and impairment expenses on \nproperty and equipment were $9.4 billion and $8.3 billion, respectively. The change in estimated useful life of our'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 45}, page_content='servers and certain network equipment was effective beginning in fiscal year 2021. The effect of this change in \naccounting estimate was a reduction in depreciation expense of $2.1 billion  for the nine months ended \nSeptember 30, 2021 . For the nine months ended September 30, 2020  and 2021, our operating lease expenses \n(including variable lease costs), were $2.1 billion and $2.5 billion, respectively. Finance leases were not material for \nthe nine months ended September 30, 2020 and 2021. \nCritical Accounting Policies and Estimates\nSee Part II, Item 7, "Critical Accounting Policies and Estimates" in our Annual Report on Form 10-K for the year \nended December 31, 2020. There have been no material changes to our critical accounting policies and estimates \nsince our Annual Report on Form 10-K for the year ended December 31, 2020. \nAvailable Information\nOur website is located at www.abc.xyz, and our investor relations website is located at www.abc.xyz/investor.'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 45}, page_content="Our Annual Reports on Form 10-K, Quarterly Reports on Form 10-Q, Current Reports on Form 8-K, and our Proxy \nStatements, and any amendments to these reports, are available through our investor relations website, free of \ncharge, after we file them with the SEC. We also provide a link to the section of the SEC's website \nat www.sec.gov that has all of the reports that we file or furnish with the SEC.\nWe webcast via our investor relations website our earnings calls and certain events we participate in or host \nwith members of the investment community. Our investor relations website also provides notifications of news or \nannouncements regarding our financial performance and other items of interest to our investors, including SEC \nTable of Contents Alphabet Inc.\n46"),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 46}, page_content='filings, investor events, press and earnings releases, and blogs. We also share Google news and product updates \non Google’s Keyword blog at https://www.blog.google/, which may be of interest or material to our investors. \nFurther, corporate governance information, including our certificate of incorporation, bylaws, governance guidelines, \nboard committee charters, and code of conduct, is also available on our investor relations website under the \nheading "Other." The content of our websites are not incorporated by reference into this Quarterly Report on Form \n10-Q or in any other report or document we file with the SEC, and any references to our websites are intended to be \ninactive textual references only.\nITEM 3. QUANTITATIVE AND QUALITATIVE DISCLOSURES ABOUT MARKET RISK\nWe are exposed to financial market risks, including changes in foreign currency exchange rates, interest rates'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 46}, page_content='and equity investment risks. Our exposure to market risk has not changed materially since December 31, 2020. For \nquantitative and qualitative disclosures about market risk, refer to Part II, Item 7A, Quantitative and Qualitative \nDisclosures About Market Risk, in our Annual Report on Form 10-K for the year ended December 31, 2020.\nITEM 4. CONTROLS AND PROCEDURES\nEvaluation of Disclosure Controls and Procedures\nOur management, with the participation of our chief executive officer and chief financial officer, evaluated the \neffectiveness of our disclosure controls and procedures pursuant to Rule 13a-15 under the Exchange Act, as of the \nend of the period covered by this Quarterly Report on Form 10-Q.\nBased on this evaluation, our chief executive officer and chief financial officer concluded that, as of \nSeptember 30, 2021, our disclosure controls and procedures are designed at a reasonable assurance level and are'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 46}, page_content='effective to provide reasonable assurance that information we are required to disclose in reports that we file or \nsubmit under the Exchange Act is recorded, processed, summarized, and reported within the time periods specified \nin the SEC’s rules and forms, and that such information is accumulated and communicated to our management, \nincluding our chief executive officer and chief financial officer, as appropriate, to allow timely decisions regarding \nrequired disclosure.\nChanges in Internal Control over Financial Reporting\nWe rely extensively on information systems to manage our business and summarize and report operating \nresults. In 2019, we began a multi-year implementation of a new global enterprise resource planning ("ERP") \nsystem, which will replace much of our existing core financial systems. The ERP system is designed to accurately \nmaintain our financial records, enhance the flow of financial information, improve data management and provide'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 46}, page_content='timely information to our management team. The implementation is expected to continue in phases over the next \nfew years. There have been no changes in our internal control over financial reporting that occurred during the \nquarter ended September 30, 2021  that have materially affected, or are reasonably likely to materially affect, our \ninternal control over financial reporting. However, as the phased implementation of the new ERP system continues, \nwe will change our processes and procedures, which in turn, could result in changes to our internal control over \nfinancial reporting. As such changes occur, we will evaluate quarterly whether such changes materially affect our \ninternal control over financial reporting.\nAs a result of COVID-19, our global workforce continued to operate primarily in a work from home environment \nfor the quarter ended September 30, 2021. While we continue to evolve our work model in response to the uneven'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 46}, page_content='effects of the ongoing pandemic around the world, we believe that our internal controls over financial reporting \ncontinue to be effective. We have continued to re-evaluate and refine our financial reporting process to provide \nreasonable assurance that we could report our financial results accurately and timely.\nLimitations on Effectiveness of Controls and Procedures\nIn designing and evaluating the disclosure controls and procedures, management recognizes that any controls \nand procedures, no matter how well designed and operated, can provide only reasonable assurance of achieving \nthe desired control objectives. In addition, the design of disclosure controls and procedures must reflect the fact that \nthere are resource constraints and that management is required to apply its judgment in evaluating the benefits of \npossible controls and procedures relative to their costs.\nTable of Contents Alphabet Inc.\n47'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 47}, page_content='PART II.  OTHER INFORMATION\nITEM 1. LEGAL PROCEEDINGS\nFor a description of our material pending legal proceedings, see Note 9 “Contingencies - Legal Matters” of the \nNotes to Consolidated Financial Statements included in Part I, Item 1 of this Quarterly Report on Form 10-Q, which \nis incorporated herein by reference.\nITEM 1A. RISK FACTORS    \nOur operations and financial results are subject to various risks and uncertainties, including those described in \nPart I, Item 1A, "Risk Factors" in our Annual Report on Form 10-K for the year ended December 31, 2020 , which \ncould adversely affect our business, financial condition, results of operations, cash flows, and the trading price of \nour common and capital stock. Below are changes to our risk factors since our Annual Report on Form 10-K for the \nyear ended December 31, 2020. \nWe cannot guarantee that any share repurchase program will be fully consummated or will enhance'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 47}, page_content='long-term stockholder value, and share repurchases could increase the volatility of our stock prices and \ncould diminish our cash reserves. \nWe engage in share repurchases of our Class A and Class C stock from time to time in accordance with \nauthorizations from the Board of Directors of Alphabet. Our repurchase program does not have an expiration date \nand does not obligate Alphabet to repurchase any specific dollar amount or to acquire any specific number of \nshares. Further, our share repurchases could affect our share trading prices, increase their volatility, reduce our \ncash reserves and may be suspended or terminated at any time, which may result in a decrease in the trading \nprices of our stock.\nThe concentration of our stock ownership limits our stockholders’ ability to influence corporate \nmatters. \nOur Class B common stock has 10 votes per share, our Class A common stock has one vote per share, and'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 47}, page_content='our Class C capital stock has no voting rights. As of September 30, 2021, Larry Page and Sergey Brin beneficially \nowned approximately 85.5% of our outstanding Class B common stock, which represented approximately 51.3% of \nthe voting power of our outstanding common stock. Through their stock ownership, Larry and Sergey have \nsignificant influence over all matters requiring stockholder approval, including the election of directors and significant \ncorporate transactions, such as a merger or other sale of our company or our assets, for the foreseeable future. In \naddition, because our Class C capital stock carries no voting rights (except as required by applicable law), the \nissuance of the Class C capital stock, including in future stock-based acquisition transactions and to fund employee \nequity incentive programs, could continue Larry and Sergey’s current relative voting power and their ability to elect'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 47}, page_content='all of our directors and to determine the outcome of most matters submitted to a vote of our stockholders. The share \nrepurchases made pursuant to our repurchase program may also affect Larry and Sergey’s relative voting power. \nThis concentrated control limits or severely restricts other stockholders’ ability to influence corporate matters and we \nmay take actions that some of our stockholders do not view as beneficial, which could reduce the market price of \nour Class A common stock and our Class C capital stock.\nTable of Contents Alphabet Inc.\n48'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 48}, page_content="ITEM 2. UNREGISTERED SALES OF EQUITY SECURITIES AND USE OF PROCEEDS\nIssuer Purchases of Equity Securities\nThe following table presents information with respect to Alphabet's repurchases of Class A common stock and \nClass C capital stock during the quarter ended September 30, 2021.\nPeriod\nTotal Number of \nClass A Shares \nPurchased \n(in thousands) \n(1)\nTotal Number of \nClass C Shares \nPurchased \n(in thousands) \n(1)\nAverage Price \nPaid per Class \nA Share (2)\nAverage Price \nPaid per Class \nC Share (2)\nTotal Number of \nShares \nPurchased as \nPart of Publicly \nAnnounced \nPrograms\n(in thousands) \n(1)\nApproximate \nDollar Value of \nShares that May \nYet Be \nPurchased \nUnder the \nProgram \n(in millions) \nJuly 1 - 31  0  1,513 $ 0.00 $ 2,632.22  1,513 $ 39,471 \nAugust 1 - 31  270  1,378 $ 2,772.38 $ 2,779.47  1,648 $ 34,895 \nSeptember 1 - 30  255  1,165 $ 2,842.50 $ 2,854.69  1,420 $ 30,844 \nTotal  525  4,056  4,581"),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 48}, page_content='(1) The repurchases are being executed from time to time, subject to general business and market conditions and other \ninvestment opportunities, through open market purchases or privately negotiated transactions, including through Rule \n10b5-1 plans. The repurchase program does not have an expiration date. See Note 10 in Part I, Item 1 of this Quarterly \nReport on Form 10-Q for additional information related to share repurchases.\n(2) Average price paid per share includes costs associated with the repurchases.\nTable of Contents Alphabet Inc.\n49'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 49}, page_content='ITEM 6. EXHIBITS\nExhibit\nNumber   Description\nIncorporated by reference herein\nForm Date\n31.01 * Certification of Chief Executive Officer pursuant to \nExchange Act Rules 13a-14(a) and 15d-14(a), as \nadopted pursuant to Section 302 of the Sarbanes-\nOxley Act of 2002\n31.02 * Certification of Chief Financial Officer pursuant to \nExchange Act Rules 13a-14(a) and 15d-14(a), as \nadopted pursuant to Section 302 of the Sarbanes-\nOxley Act of 2002\n32.01 ‡ Certifications of Chief Executive Officer and Chief \nFinancial Officer pursuant to 18 U.S.C. Section 1350, \nas adopted pursuant to Section 906 of the Sarbanes-\nOxley Act of 2002\n101.INS * Inline XBRL Instance Document - the instance \ndocument does not appear in the Interactive Data \nFile because its XBRL tags are embedded within the \nInline XBRL document.\n101.SCH * Inline XBRL Taxonomy Extension Schema \nDocument\n101.CAL * Inline XBRL Taxonomy Extension Calculation \nLinkbase Document\n101.DEF * Inline XBRL Taxonomy Extension Definition Linkbase'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 49}, page_content='Document\n101.LAB * Inline XBRL Taxonomy Extension Label Linkbase \nDocument\n101.PRE * Inline XBRL Taxonomy Extension Presentation \nLinkbase Document\n104 Cover Page Interactive Data File (formatted as Inline \nXBRL and contained in Exhibit 101)\n__________________________ \n* Filed herewith.\n‡ Furnished herewith.\nTable of Contents Alphabet Inc.\n50'),
#  Document(metadata={'source': './2021-q3-alphabet-10q.pdf', 'page': 50}, page_content="SIGNATURE\nPursuant to the requirements of the Securities Exchange Act of 1934, the registrant has duly caused this \nreport to be signed on its behalf by the undersigned thereunto duly authorized.\nALPHABET INC.\nOctober 26, 2021 By: /s/    RUTH M. PORAT        \nRuth M. Porat\nSenior Vice President and Chief Financial Officer\nALPHABET INC.\nOctober 26, 2021 By: /s/    AMIE THUENER O'TOOLE        \nAmie Thuener O'Toole\nVice President and Chief Accounting Officer\nTable of Contents Alphabet Inc.\n51")]

# %% [markdown]
# ## Load the Content in a Vector Store

# %%
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import DocArrayInMemorySearch

vectorstore = DocArrayInMemorySearch.from_documents(
    documents, embedding=OpenAIEmbeddings()
)

# %% [markdown]
# ## Create a Knowledge Base

# %% [markdown]
# Let's start by loading the content in a pandas DataFrame.

# %%
import pandas as pd

df = pd.DataFrame([d.page_content for d in documents], columns=["text"])
df.head(10)
# Out:
#                                                 text
# 0  UNITED STATES\nSECURITIES AND EXCHANGE COMMISS...
# 1  Mountain View, CA 94043\n(Address of principal...
# 2  Indicate by check mark whether the registrant ...
# 3  complying with any new or revised financial ac...
# 4  Alphabet Inc.\nForm 10-Q\nFor the Quarterly Pe...
# 5  Item 1A Risk Factors 48\nItem 2 Unregistered S...
# 6  Note About Forward-Looking Statements\nThis Qu...
# 7  • our expectation that the portion of our reve...
# 8  • our expectation that our foreign exchange ri...
# 9  marketing expenses, and general and administra...

# %% [markdown]
# We can now create a Knowledge Base using the DataFrame we created before.

# %%
from giskard.rag import KnowledgeBase

knowledge_base = KnowledgeBase(df)

# %% [markdown]
# ## Generate the Test Set

# %%
from giskard.rag import generate_testset

testset = generate_testset(
    knowledge_base,
    num_questions=60,
    agent_description="A chatbot answering questions about the earnings of Alphabet Inc. in Q3, 2021",
)
# Out:
# Generating questions: 100%|██████████| 60/60 [07:50<00:00,  7.83s/it]

# %% [markdown]
# Let's display a few samples from the test set.

# %%
test_set_df = testset.to_pandas()

for index, row in enumerate(test_set_df.head(3).iterrows()):
    print(f"Question {index + 1}: {row[1]['question']}")
    print(f"Reference answer: {row[1]['reference_answer']}")
    print("Reference context:")
    print(row[1]['reference_context'])
    print("******************", end="\n\n")
# Out:
# Question 1: Where can I find Google's corporate governance information?
# Reference answer: Google's corporate governance information, including certificate of incorporation, bylaws, governance guidelines, board committee charters, and code of conduct, is available on their investor relations website under the heading 'Other.'
# Reference context:
# Document 171: filings, investor events, press and earnings releases, and blogs. We also share Google news and product updates
# on Google’s Keyword blog at https://www.blog.google/, which may be of interest or material to our investors.
# Further, corporate governance information, including our certificate of incorporation, bylaws, governance guidelines,
# board committee charters, and code of conduct, is also available on our investor relations website under the
# heading "Other." The content of our websites are not incorporated by reference into this Quarterly Report on Form
# 10-Q or in any other report or document we file with the SEC, and any references to our websites are intended to be
# inactive textual references only.
# ITEM 3. QUANTITATIVE AND QUALITATIVE DISCLOSURES ABOUT MARKET RISK
# We are exposed to financial market risks, including changes in foreign currency exchange rates, interest rates
# ******************
#
# Question 2: What was the net income of Alphabet Inc. for the three months ended September 30, 2021?
# Reference answer: The net income of Alphabet Inc. for the three months ended September 30, 2021 was $18,936 million.
# Reference context:
# Document 17: Alphabet Inc.
# CONSOLIDATED STATEMENTS OF INCOME
# (in millions, except per share amounts; unaudited)
# Three Months Ended Nine Months Ended
# September 30, September 30,
# 2020 2021 2020 2021
# Revenues $ 46,173 $ 65,118 $ 125,629 $ 182,312
# Costs and expenses:
# Cost of revenues  21,117  27,621  58,652  77,951
# Research and development  6,856  7,694  20,551  22,854
# Sales and marketing  4,231  5,516  12,632  15,308
# General and administrative  2,756  3,256  8,221  9,370
# Total costs and expenses  34,960  44,087  100,056  125,483
# Income from operations  11,213  21,031  25,573  56,829
# Other income (expense), net  2,146  2,033  3,820  9,503
# Income before income taxes  13,359  23,064  29,393  66,332
# Provision for income taxes  2,112  4,128  4,351  10,941
# Net income $ 11,247 $ 18,936 $ 25,042 $ 55,391
# Basic net income per share of Class A and B
# common stock and Class C capital stock $ 16.55 $ 28.44 $ 36.69 $ 82.76
# Diluted net income per share of Class A and B
#
# Document 19: Alphabet Inc.
# CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME
# (in millions; unaudited)
# Three Months Ended Nine Months Ended
#  September 30, September 30,
#  2020 2021 2020 2021
# Net income $ 11,247 $ 18,936 $ 25,042 $ 55,391
# Other comprehensive income (loss):
# Change in foreign currency translation adjustment  459  (614)  193  (671)
# Available-for-sale investments:
# Change in net unrealized gains (losses)  (19)  (159)  1,346  (699)
# Less: reclassification adjustment for net (gains) losses
# included in net income  (73)  (57)  (391)  (121)
# Net change, net of income tax benefit (expense) of $27,
# $63, $(274) and $235  (92)  (216)  955  (820)
# Cash flow hedges:
# Change in net unrealized gains (losses)  (48)  292  244  429
# Less: reclassification adjustment for net (gains) losses
# included in net income  23  (60)  (114)  21
# Net change, net of income tax benefit (expense) of $8,
# $(54), $(38) and $(89)  (25)  232  130  450
# Other comprehensive income (loss)  342  (598)  1,278  (1,041)
#
# Document 25: Alphabet Inc.
# CONSOLIDATED STATEMENTS OF CASH FLOWS
# (in millions; unaudited)
# Nine Months Ended
# September 30,
# 2020 2021
# Operating activities
# Net income $ 25,042 $ 55,391
# Adjustments:
# Depreciation and impairment of property and equipment  9,366  8,340
# Amortization and impairment of intangible assets  606  662
# Stock-based compensation expense  9,768  11,422
# Deferred income taxes  (280)  192
# Gain on debt and equity securities, net  (3,055)  (9,792)
# Other  875  (199)
# Changes in assets and liabilities, net of effects of acquisitions:
# Accounts receivable  (1,079)  (3,276)
# Income taxes, net  469  2,744
# Other assets  (592)  (1,447)
# Accounts payable  (269)  (874)
# Accrued expenses and other liabilities  891  2,763
# Accrued revenue share  277  386
# Deferred revenue  428  406
# Net cash provided by operating activities  42,447  66,718
# Investing activities
# Purchases of property and equipment  (16,802)  (18,257)
# Purchases of marketable securities  (104,932)  (95,106)
#
# Document 21: Alphabet Inc.
# CONSOLIDATED STATEMENTS OF STOCKHOLDERS’ EQUITY
# (In millions, except share amounts which are reflected in thousands; unaudited)
#  Three Months Ended September 30, 2020
#
# Class A and Class B Common
# Stock, Class C Capital Stock
# and Additional Paid-In Capital
# Accumulated
# Other
# Comprehensive
# Income (Loss)
# Retained
# Earnings
# Total
# Stockholders’
# Equity Shares    Amount
# Balance as of June 30, 2020  681,215 $ 55,937 $ (296) $ 151,681 $ 207,322
# Common and capital stock issued  1,669  15  0  0  15
# Stock-based compensation expense  0  3,230  0  0  3,230
# Tax withholding related to vesting of
# restricted stock units and other  0  (1,339)  0  0  (1,339)
# Repurchases of capital stock  (5,160)  (536)  0  (7,361)  (7,897)
# Sale of interest in consolidated entities  0  0  0  0  0
# Net income  0  0  0  11,247  11,247
# Other comprehensive income (loss)  0  0  342  0  342
# Balance as of September 30, 2020  677,724 $ 57,307 $ 46 $ 155,567 $ 212,920
#  Nine Months Ended September 30, 2020
# ******************
#
# Question 3: What was the amount of unrecognized compensation cost related to unvested employee RSUs for Alphabet Inc. as of September 30, 2021?
# Reference answer: As of September 30, 2021, there was $28.2 billion of unrecognized compensation cost related to unvested employee RSUs.
# Reference context:
# Document 102: As of September 30, 2021 , there was $28.2 billion  of unrecognized compensation cost related to unvested
# employee RSUs. This amount is expected to be recognized over a weighted-average period of 2.6 years.
# Table of Contents Alphabet Inc.
# 30
# ******************

# %% [markdown]
# Let's now save the test set to a file:

# %%
testset.save("test-set-alphabet-q1-2021.jsonl")

# %% [markdown]
# ## Prepare the Prompt Template

# %%
from langchain.prompts import PromptTemplate

template = """
Answer the question based on the context below. If you can't 
answer the question, reply "I don't know".

Context: {context}

Question: {question}
"""

prompt = PromptTemplate.from_template(template)
print(prompt.format(context="Here is some context", question="Here is a question"))
# Out:
# Answer the question based on the context below. If you can't
# answer the question, reply "I don't know".
#
# Context: Here is some context
#
# Question: Here is a question

# %% [markdown]
# ## Create the RAG Chain

# %% [markdown]
# Create a retriever from the Vector Store that will allow us to get the top similar documents to a given question.

# %%
retriever = vectorstore.as_retriever()
retriever.get_relevant_documents("What is the Machine Learning School?")
# Out:
# C:\Users\agnib\AppData\Local\Temp\ipykernel_22380\814621628.py:2: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   retriever.get_relevant_documents("What is the Machine Learning School?")
# [Document(metadata={'source': 'https://www.ml.school/', 'title': "Building Machine Learning Systems That Don't Suck", 'description': "A live, interactive program that'll help you build production-ready machine learning systems from the ground up.", 'language': 'en'}, page_content="program will help you unlearn what you think machine learning is. It's a practical, hands-on class where you'll learn from years of experience and real-world examples.When you join, you get lifetime access to the following:18 hours of live, interactive sessions. We'll use this time to discuss the first principles behind building machine learning systems.10 hours of step-by-step coding instructions. These practical sessions will show you how to build an end-to-end system from scratch.A final project where you'll build a complete solution and receive direct feedback on your work.100 coding assignments and practice questions.The entire source code of a working production system. It's yours. You can change and use it as you see fit.A private community where you'll collaborate with thousands of people from different backgrounds.Direct access to your instructor.Lifetime access to every past and future cohort.Program certificate upon completion.And the best part is that you only pay once to"),
#  Document(metadata={'source': 'https://www.ml.school/', 'title': "Building Machine Learning Systems That Don't Suck", 'description': "A live, interactive program that'll help you build production-ready machine learning systems from the ground up.", 'language': 'en'}, page_content='Building Machine Learning Systems That Don\'t Suck"This is the best machine learning course I\'ve done. Worth every cent."Jose Reyes, AI/ML at Cevo AustraliaBuilding Machine Learning Systems That Don\'t SuckA live, interactive program that\'ll help you build production-ready machine learning systems from the ground up.Next cohort:\xa0February 3 - 20, 2025Check the schedule for more details about upcoming cohorts.I want to join!Sign inLearn how to design, build, deploy, and scale machine learning systems to solve real-world problems.I\'ll lose my mind if I see another book or course teaching people the same basic ideas for the hundredth time. Most people are stuck in beginner mode, and finding help to solve real-world problems is hard.I want to change that.I started writing software 30 years ago. I\'ve written pipelines and trained models for some of the largest companies in the world. I want to show you how to do the same.This is the class I wish I had taken when I started.This program will'),
#  Document(metadata={'source': 'https://www.ml.school/', 'title': "Building Machine Learning Systems That Don't Suck", 'description': "A live, interactive program that'll help you build production-ready machine learning systems from the ground up.", 'language': 'en'}, page_content='that make systems work.You are ready to put in the work to succeed."I have learned a ton from Santiago in his class and it was actually what helped inspire me and get into the MLOps work that I\'m doing now. Truly one of the most helpful online courses for doing real, full-scale machine learning."Brian H. HoughSoftware EngineerWhat Will You Learn?You\'ll come out with practical skills and insights into what it takes to build systems that work in the real world.Here is a summary of what makes this program unique:You\'ll design and write the code to build an end-to-end machine learning system starting from scratch.You\'ll learn best practices to tackle the most significant challenges machine learning engineers face to build, evaluate, run, monitor, and maintain machine learning systems in real-world scenarios.You\'ll learn how to use techniques like active learning, distributed training, adversarial validation, human-in-the-loop deployments, model compression, test-time augmentation, testing'),
#  Document(metadata={'source': 'https://www.ml.school/', 'title': "Building Machine Learning Systems That Don't Suck", 'description': "A live, interactive program that'll help you build production-ready machine learning systems from the ground up.", 'language': 'en'}, page_content="only pay once to join. There are no monthly fees. No annual fees. No hidden costs. You pay once to join and benefit forever until the end of time.The program won't be easy. It'll take time and effort. But if you want to use machine learning to solve real-world problems, this is the class you don't want to miss.Who Is This Program For?This is a practical, hands-on program for technical professionals who are ready to put in the work.This program is for software engineers, data scientists, data analysts, machine learning engineers, technical managers, and anyone anyone who wants to use machine learning to solve real-world problems.Here are the criteria to succeed in the program:You have experience writing code. We'll use Python throughout the class, but you won't have any problems if you know any other language.You are familiar with basic machine learning terminology. This is not an introductory class. We'll move quickly over the basics to focus on the fundamental ideas that make systems")]

# %% [markdown]
# We can now create our chain.

# %%
from langchain.chat_models import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from operator import itemgetter

model = ChatOpenAI(openai_api_key=OPENAI_API_KEY, model=MODEL)

chain = (
    {
        "context": itemgetter("question") | retriever,
        "question": itemgetter("question"),
    }
    | prompt
    | model
    | StrOutputParser()
)
# Out:
# C:\Users\agnib\AppData\Local\Temp\ipykernel_22380\2743684902.py:5: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   model = ChatOpenAI(openai_api_key=OPENAI_API_KEY, model=MODEL)

# %% [markdown]
# Let's make sure the chain works by testing it with a simple question.

# %%
chain.invoke({"question": "What is the Machine Learning School?"})
# Out:
# 'The Machine Learning School is a live, interactive program that helps individuals build production-ready machine learning systems from scratch. It offers practical, hands-on classes, coding instructions, a final project, coding assignments, access to a private community, direct access to instructors, and lifetime access to past and future cohorts.'

# %% [markdown]
# ## Evaluating the Model on the Test Set

# %% [markdown]
# We need to create a function that invokes the chain with a specific question and returns the answer.

# %%
def answer_fn(question, history=None):
    return chain.invoke({"question": question})

# %% [markdown]
# We can now use the `evaluate()` function to evaluate the model on the test set. This function will compare the answers from the chain with the reference answers in the test set.

# %%
from giskard.rag import evaluate

report = evaluate(answer_fn, testset=testset, knowledge_base=knowledge_base)
# Out:
# Asking questions to the agent: 100%|██████████| 60/60 [02:07<00:00,  2.13s/it]
# CorrectnessMetric evaluation: 100%|██████████| 60/60 [02:16<00:00,  2.27s/it]

# %% [markdown]
# Let now display the report.
#
# Here are the five components of our RAG application:
#
# * **Generator**: This is the LLM used in the chain to generate the answers.
# * **Retriever**: This is the retriever that fetches relevant documents from the knowledge base according to a query.
# * **Rewriter**: This is a component that rewrites the user query to make it more relevant to the knowledge base or to account for chat history.
# * **Router**: This is a component that filters the query of the user based on his intentions.
# * **Knowledge Base**: This is the set of documents given to the RAG to generate the answers.

# %%
display(report)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a3485b5d-c873-4afd-af28-4ecb83e5e585">Loading BokehJS ...</span>
#     </div>
# <!DOCTYPE html>
#
#
# <style>
#     body{
#   background: #18181B;
# }
#
# .main{
#   font-family: "Noto Sans", ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, "Helvetica Neue", Arial, sans-serif, "Apple Color Emoji", "Segoe UI Emoji", "Segoe UI Symbol", "Noto Color Emoji";
#   color: #FDFDFD;
# }
#
# h1 {
#   font-size: 2.5rem;
#   color: white;
# }
#
# h3 {
#   font-size: 1.5rem;
#   background: #0c087c;
#   padding: 10px;
#   margin: 0px;
#   border: 1px solid #6b7280;}
#
# .extended-title{
#   width:100%;
# }
#
# #gsk-overview{
#   display:flex;
# }
#
# h4 {
#   font-size: 1rem;
#   background: #27272A;
#   padding: 10px;
#   margin: 0px;
#   border-bottom: 1px solid #6b7280;
# }
#
# h2 {
#   font-size: 1.5rem;
#   margin-top: 3px;
#   color:#000000;
# }
#
# .header{
#   display: flex;
#   justify-content: center;
#   align-items: center;
# }
# .header > * {
#   margin-inline: 20px;
# }
#
# .flex-row {
#   display: flex;
#   flex-direction: row;
#   padding:10px;
#   border: 1px solid #27272A;
# }
#
# .flex-row>div {
#   flex: auto;
#   box-sizing: border-box;
#   display: flex;
#   flex-direction: column;
#   justify-content: center;
#   align-items: center;
# }
#
# progress[value] {
#   --background: #6D6D6D;
#   -webkit-appearance: none;
#   -moz-appearance: none;
#   appearance: none;
#   border: none;
#   height: 4px;
#   margin: 0 10px;
#   border-radius: 10em;
#   background: var(--background);
# }
#
# progress[value]::-webkit-progress-bar {
#   border-radius: 10em;
#   background: var(--background);
# }
#
# progress[value]::-webkit-progress-value {
#   border-radius: 10em;
#   background: var(--color);
# }
#
# progress[value]::-moz-progress-bar {
#   border-radius: 10em;
#   background: var(--color);
# }
#
# label {
#   font-size: 20px;
#   font-weight: bold;
#   display: block;
#   margin: 20px 0;
# }
#
# .tab {
#   overflow: hidden;
#   border: 1px solid #27272A;
#   background-color: #27272A;
# }
#
# .tab button {
#   background-color: inherit;
#   float: left;
#   border: none;
#   outline: none;
#   cursor: pointer;
#   padding: 14px 16px;
#   transition: 0.3s;
#   color: #ffffff;
#   font-size:1.2rem;
# }
#
# .tab div {
#   background-color: inherit;
#   float: left;
#   border: none;
#   outline: none;
#   cursor: pointer;
#   padding: 14px 16px;
#   transition: 0.3s;
#   color: #ffffff;
#   font-size: 1.2rem;
# }
#
# .tab button:hover {
#   background-color: #18181B;
# }
#
# .tab-title{
#   font-size: 1.5rem;
#   font-weight: bold;
#   margin-bottom:-5px;
# }
#
# .tab button.active {
#   background-color: #18181B;
#   border-top: 1px solid #6b7280;
#   border-bottom: 1px solid #18181B;
#   border-left: 1px solid #6b7280;
#   border-right: 1px solid #6b7280;
# }
#
# .tabcontent {
#   display: none;
#   padding: 6px 12px;
#   background: #18181B;
#   border: 1px solid #27272A;
#   border-top: 1px solid #6b7280;
#   margin-top: -2px;
# }
#
# #gsk-advice {
#   display: flex;
#   justify-content: center;
# }
#
# #gsk-metrics{
#   width:100%;
# }
#
# #recommendation {
#   margin-top: 20px;
#   padding: 20px;
#   border-radius: 10px;
#   background-color: #e1ce86;
#   color: #27272A;
#   width:95%;
#   box-shadow: 0 4px 8px 0 #000000, 0 6px 20px 0 #000000;
#   font-size: 12pt;
# }
#
# .separator {
#   margin: 20px 0;
# }
#
# .separator-border {
#   margin: 20px 0;
#   border-bottom: 1px solid #6b7280;
# }
#
# #gsk-rag{
#   margin: 32px 28px;
#   padding: 12px 24px;
#   background-color: #111516;
# }
#
# .section-container {
#   margin-bottom: 32px;
# }
#
#   .components-container {
#     display: flex;
#     flex-flow: row wrap;
#     align-items: flex-start;
#     gap: 0 32px;
#   }
#
#     .component-card {
#       background-color: #14191B;
#       border-radius: 16px;
#       padding: 28px 32px 32px 32px;
#       display: flex;
#       flex-flow: column;
#       align-items: center;
#       margin-top: 32px;
#       flex-grow: 1;
#     }
#
#     .component-title {
#       font-size: 12px;
#       font-weight: 500;
#       color: #B1B1B1;
#       padding-bottom: 8px;
#     }
#
#     .component-value {
#       font-size: 32px;
#       font-weight: 500;
#       padding-bottom: 12px;
#     }
#
#       .text-green {
#         color: #04B543;
#       }
#
#       .text-orange {
#         color: #E76E0F;
#       }
#
#       .text-red {
#         color: #EA3829;
#       }
#
#       .tooltip {
#         position: relative;
#         display: inline-block;
#       }
#
#       .tooltip .tooltiptext {
#         visibility: hidden;
#         width: 120px;
#         background-color: #464646;
#         color: #E6E6E6;
#         text-align: center;
#         border-radius: 6px;
#         position: absolute;
#         z-index: 1;
#         top: 150%;
#         left: 50%;
#         margin-left: -60px;
#         font-size: 12px;
#         padding: 12px;
#       }
#
#       .tooltip .tooltiptext::after {
#         content: "";
#         position: absolute;
#         bottom: 100%;
#         left: 50%;
#         margin-left: -5px;
#         border-width: 5px;
#         border-style: solid;
#         border-color: transparent transparent black transparent;
#       }
#
#       .tooltip:hover .tooltiptext {
#         visibility: visible;
#       }
#
#     .overall-card {
#       background-color: #026836;
#       border-radius: 16px;
#       padding: 28px 32px 32px 32px;
#       display: flex;
#       flex-flow: column;
#       align-items: center;
#       justify-content: center;
#       margin-top: 32px;
#       flex-grow: 1;
#     }
#
#     .overall-title {
#       font-size: 12px;
#       font-weight: 500;
#       color: #E6E6E6;
#       padding: 14px 0 8px 0;
#       text-transform: uppercase;
#      }
#
#     .overall-value {
#       font-size: 32px;
#       font-weight: 500;
#       padding-bottom: 12px;
#       color: #E6E6E6;
#     }
#
# .section-title {
#   font-size: 12px;
#   color: #B1B1B1;
#   margin-bottom: 20px;
#   text-align: left;
#   width: 100%;
# }
#
# .section-content {
#   color: #E6E6E6;
#   font-size: 20px;
#   line-height: 1.5;
# }
#
# .section-card {
#   background-color: #14191B;
#   border-radius: 16px;
#   padding: 28px 32px 32px 32px;
#   display: flex;
#   flex-flow: column;
#   align-items: center;
# }
#
# .correctness-indicator{
#   padding: 20px;
#   border-radius: 50px;
#   font-size: 16pt;
#   box-shadow: 0 4px 8px 0 #000000, 0 6px 20px 0 #000000;
#   text-align: center;
# }
#
# .metric-title{
#   margin: -2px;
#   border-bottom: none;
# }
#
# .hist-row {
#   display: flex;
#   flex-direction: row;
#   padding: 10px;
#   justify-content: space-around;
#   width: 85%;
# }
#
# .hist-row>div {
#   flex: auto;
#   box-sizing: border-box;
#   display: flex;
#   flex-direction: column;
#   justify-content: center;
#   align-items: center;
#   padding-left: 1%;
#   padding-right: 1%;
# }
#
# .tab-row{
#   display: flex;
#   flex-direction: column;
#   align-items: center;
# }
#
# #component-table{
#   width:50%;
#   margin-top: 10px;
# }
#
# .green{
#   background-color: #0a980a;
# }
#
# .orange {
#   background-color: #e5b62a;
# }
#
# .red {
#   background-color: #ba0e0e;
# }
#
# .progress-green {
#   --color: #04B543;
# }
#
# .progress-orange {
#   --color: #E76E0F;
# }
#
# .progress-red {
#   --color: #EA3829;
# }
#
# .corr-plot{
#   flex: 1;
#   padding-left: 2%;
# }
#
# .tooltip-text {
#   position: absolute;
#   display: none;
#   visibility: hidden;
#   z-index: 1;
#   top: 100%;
#   left: 0%;
#   width: 100%;
#   color: white;
#   font-size: 12px;
#   background-color: #2d3d4c;
#   border-radius: 10px;
#   padding: 10px 15px 10px 15px;
# }
#
# #fade {
#   opacity: 1;
#   transition: opacity 0.5s;
# }
#
# #delay {
#   opacity: 0;
#   transition: opacity 0.2s;
#   transition-delay: 1s;
# }
#
# td {
#   position: relative;
# }
#
# tr:hover .tooltip-text {
#   display: block;
#   visibility: visible;
# }
#
# .tr:hover #fade {
#   opacity: 1;
# }
#
# .tr:hover #delay {
#   opacity: 1;
# }
#
# .callout {
#   padding: 0.5rem 1rem 0.5rem 3rem;
#   background: #D9EDF9;
#   border: 3px solid #0088D1;
#   color: #272eb5;
#   position: relative;
#   max-width: 40rem;
#   border-radius: 10px;
#   margin-top: 10%;
#   font-size: 11pt;
# }
#
# .callout-icon {
#   content: "";
#
#   /* SVG via a data URI! */
#   background-size: cover;
#   width: 1.5rem;
#   height: 1.5rem;
#   display: block;
#   position: absolute;
#   left: 0.9rem;
#   top: 1.1rem;
# }
#
# .callout-icon svg{
#   fill: #016ca7;
# }
# .callout p+p {
#   margin-top: 1em;
# }
#
# .callout a {
#   color: #272eb5;
#   font-weight: bold;
# }
#
# #gsk-logo {
#   padding-top: 10px;
# }
# </style>
# <script src="https://cdn.bokeh.org/bokeh/release/bokeh-3.3.4.min.js" integrity="sha384-5QIrjQuyo4I/x6DK/Sau33lcA3hT2TCZGr9vbk+2ebd7Da6FnR1amdM+9B5xOrSf" crossorigin="anonymous"></script>
# <script

# %%
report.to_html("report.html")

# %% [markdown]
# We can display the correctness results organized by question type.

# %%
report.correctness_by_question_type()
# Out:
#                      correctness
# question_type
# complex                      1.0
# conversational               0.4
# distracting element          0.4
# double                       0.8
# simple                       0.7
# situational                  0.6

# %% [markdown]
# We can also display the specific failures.

# %%
report.get_failures()
# Out:
#                                                                                question  \
# id
# 21b81dea-8d65-4b4c-a501-e7e28fabce54  What are some of the topics covered in the sec...
# 70e621dd-1903-43ef-9737-bce15a9449e9  What skills will I gain from this Machine Lear...
# 6febe0b2-71a4-4f54-b12b-b5c910e9427e  What are some of the topics covered in the sec...
# 96922868-8c9c-4799-97d3-bb0f0a29df3b  Considering the course content covered until 2...
# 321c31d4-e195-4dae-92d3-0f8c75cc07d6  What practical skills and insights, relevant t...
# 340a2da0-deba-416e-bb71-40227c528bd2  In the context of the Machine Learning School ...
# ed4c5c42-9abc-4afd-b8c9-b16c8d04d06d  Who possesses the copyright for the content of...
# c0e9ccfb-3f6d-452b-946f-c09e79903825  What are the benefits of joining the machine l...
# 5e31f866-28da-4e68-9b36-ae9e44369efe  Considering that beginners might find the pace...
# 44c909f2-e7a5-4776-a158-9f473c7ca075  I'm considering joining the Machine Learning S...
# 0dedcd83-e131-4790-88b6-601c40b92d4e  Hello there, as a lifelong learner, I'm intere...
# 5e451298-d53a-4089-abd9-2d1ef721407c  Hey, I'm a computer science graduate student a...
# 9995d386-fc1f-4d3f-8abb-5667e2e3e58a  As a potential student considering enrolling i...
# 1804021f-4260-4c4b-bde4-7011b5bb936d  What are the benefits of joining the Machine L...
# 98afe542-2142-4d23-aec4-6e8b523497f7  Who holds the copyright for the content and ho...
# f50e4608-5aa7-47e8-975d-7fddf2f989db                    What benefits could this bring?
# 2ab5fabc-f970-4baf-a6ba-89d43e97ae62                     What are the benefits of this?
# 57de64ce-17a8-4585-9a98-2653bcb98932                   Could you tell me these details?
# 91e4ab38-5f4f-4a03-8a8b-9dc965e6e608           Could you tell me what are some of them?
# 62c9737e-e110-48a9-a282-881a258448cc   Who is this person and what is their experience?
# 44f564ce-9a45-4b97-96df-a34db9c4545e                What are its benefits and features?
#
#                                                                        reference_answer  \
# id
# 21b81dea-8d65-4b4c-a501-e7e28fabce54  The second session of the course covers topics...
# 70e621dd-1903-43ef-9737-bce15a9449e9  You'll come out with practical skills and insi...
# 6febe0b2-71a4-4f54-b12b-b5c910e9427e  The second session of the course covers topics...
# 96922868-8c9c-4799-97d3-bb0f0a29df3b  Session 2 covers topics such as data cleaning,...
# 321c31d4-e195-4dae-92d3-0f8c75cc07d6  You'll gain practical skills and insights into...
# 340a2da0-deba-416e-bb71-40227c528bd2  The instructor of the Machine Learning School ...
# ed4c5c42-9abc-4afd-b8c9-b16c8d04d06d  The copyright for the content is held by Tidei...
# c0e9ccfb-3f6d-452b-946f-c09e79903825  When you join the machine learning program, yo...
# 5e31f866-28da-4e68-9b36-ae9e44369efe  When you join the machine learning program, yo...
# 44c909f2-e7a5-4776-a158-9f473c7ca075  The instructor of the program is Santiago. He ...
# 0dedcd83-e131-4790-88b6-601c40b92d4e  The program lasts for 3 weeks. The next cohort...
# 5e451298-d53a-4089-abd9-2d1ef721407c  The training program lasts for 3 weeks, with 1...
# 9995d386-fc1f-4d3f-8abb-5667e2e3e58a  The cost of the program is $300. This is a one...
# 1804021f-4260-4c4b-bde4-7011b5bb936d  Joining the Machine Learning School program gi...
# 98afe542-2142-4d23-aec4-6e8b523497f7  The content is copyrighted by Tideily LLC and ...
# f50e4608-5aa7-47e8-975d-7fddf2f989db  When you join the Machine Learning program, yo...
# 2ab5fabc-f970-4baf-a6ba-89d43e97ae62  The benefits of joining the program include 18...
# 57de64ce-17a8-4585-9a98-2653bcb98932  The program lasts for 3 weeks, and the next co...
# 91e4ab38-5f4f-4a03-8a8b-9dc965e6e608  You will learn to design and write the code to...
# 62c9737e-e110-48a9-a282-881a258448cc  The instructor of the program is Santiago. He ...
# 44f564ce-9a45-4b97-96df-a34db9c4545e  The machine learning program offers 18 hours o...
#
#                                                                       reference_context  \
# id
# 21b81dea-8d65-4b4c-a501-e7e28fabce54  Document 7: to determine how much data you nee...
# 70e621dd-1903-43ef-9737-bce15a9449e9  Document 3: that make systems work.You are rea...
# 6febe0b2-71a4-4f54-b12b-b5c910e9427e  Document 7: to determine how much data you nee...
# 96922868-8c9c-4799-97d3-bb0f0a29df3b  Document 7: to determine how much data you nee...
# 321c31d4-e195-4dae-92d3-0f8c75cc07d6  Document 3: that make systems work.You are rea...
# 340a2da0-deba-416e-bb71-40227c528bd2  Document 9: learning, beginners will find the ...
# ed4c5c42-9abc-4afd-b8c9-b16c8d04d06d  Document 10: then, thousands of students have ...
# c0e9ccfb-3f6d-452b-946f-c09e79903825  Document 6: as you'd like. No restrictions.Enj...
# 5e31f866-28da-4e68-9b36-ae9e44369efe  Document 1: program will help you unlearn what...
# 44c909f2-e7a5-4776-a158-9f473c7ca075  Document 9: learning, beginners will find the ...
# 0dedcd83-e131-4790-88b6-601c40b92d4e  Document 4: testing in production, among many ...
# 5e451298-d53a-4089-abd9-2d1ef721407c  Document 4: testing in production, among many ...
# 9995d386-fc1f-4d3f-8abb-5667e2e3e58a  Document 5: Wednesdays, we'll host office hour...
# 1804021f-4260-4c4b-bde4-7011b5bb936d  Document 1: program will help you unlearn what...
# 98afe542-2142-4d23-aec4-6e8b523497f7  Document 10: then, thousands of students have ...
# f50e4608-5aa7-47e8-975d-7fddf2f989db  Document 1: program will help you unlearn what...
# 2ab5fabc-f970-4baf-a6ba-89d43e97ae62  Document 1: program will help you unlearn what...
# 57de64ce-17a8-4585-9a98-2653bcb98932  Document 4: testing in production, among many ...
# 91e4ab38-5f4f-4a03-8a8b-9dc965e6e608  Document 3: that make systems work.You are rea...
# 62c9737e-e110-48a9-a282-881a258448cc  Document 9: learning, beginners will find the ...
# 44f564ce-9a45-4b97-96df-a34db9c4545e  Document 2: only pay once to join. There are n...
#
#                                                                    conversation_history  \
# id
# 21b81dea-8d65-4b4c-a501-e7e28fabce54                                                 []
# 70e621dd-1903-43ef-9737-bce15a9449e9                                                 []
# 6febe0b2-71a4-4f54-b12b-b5c910e9427e                                                 []
# 96922868-8c9c-4799-97d3-bb0f0a29df3b                                                 []
# 321c31d4-e195-4dae-92d3-0f8c75cc07d6                                                 []
# 340a2da0-deba-416e-bb71-40227c528bd2                                                 []
# ed4c5c42-9abc-4afd-b8c9-b16c8d04d06d                                                 []
# c0e9ccfb-3f6d-452b-946f-c09e79903825                                                 []
# 5e31f866-28da-4e68-9b36-ae9e44369efe                                                 []
# 44c909f2-e7a5-4776-a158-9f473c7ca075                                                 []
# 0dedcd83-e131-4790-88b6-601c40b92d4e                                                 []
# 5e451298-d53a-4089-abd9-2d1ef721407c                                                 []
# 9995d386-fc1f-4d3f-8abb-5667e2e3e58a                                                 []
# 1804021f-4260-4c4b-bde4-7011b5bb936d                                                 []
# 98afe542-2142-4d23-aec4-6e8b523497f7                                                 []
# f50e4608-5aa7-47e8-975d-7fddf2f989db  [{'role': 'user', 'content': 'I'm considering ...
# 2ab5fabc-f970-4baf-a6ba-89d43e97ae62  [{'role': 'user', 'content': 'I'm considering ...
# 57de64ce-17a8-4585-9a98-2653bcb98932  [{'role': 'user', 'content': 'I'm interested i...
# 91e4ab38-5f4f-4a03-8a8b-9dc965e6e608  [{'role': 'user', 'content': 'I am interested ...
# 62c9737e-e110-48a9-a282-881a258448cc  [{'role': 'user', 'content': 'I'm referring to...
# 44f564ce-9a45-4b97-96df-a34db9c4545e  [{'role': 'user', 'content': 'Regarding the ma...
#
#                                                                                metadata  \
# id
# 21b81dea-8d65-4b4c-a501-e7e28fabce54  {'question_type': 'simple', 'seed_document_id'...
# 70e621dd-1903-43ef-9737-bce15a9449e9  {'question_type': 'simple', 'seed_document_id'...
# 6febe0b2-71a4-4f54-b12b-b5c910e9427e  {'question_type': 'simple', 'seed_document_id'...
# 96922868-8c9c-4799-97d3-bb0f0a29df3b  {'question_type': 'distracting element', 'seed...
# 321c31d4-e195-4dae-92d3-0f8c75cc07d6  {'question_type': 'distracting element', 'seed...
# 340a2da0-deba-416e-bb71-40227c528bd2  {'question_type': 'distracting element', 'seed...
# ed4c5c42-9abc-4afd-b8c9-b16c8d04d06d  {'question_type': 'distracting element', 'seed...
# c0e9ccfb-3f6d-452b-946f-c09e79903825  {'question_type': 'distracting element', 'seed...
# 5e31f866-28da-4e68-9b36-ae9e44369efe  {'question_type': 'distracting element', 'seed...
# 44c909f2-e7a5-4776-a158-9f473c7ca075  {'question_type': 'situational', 'seed_documen...
# 0dedcd83-e131-4790-88b6-601c40b92d4e  {'question_type': 'situational', 'seed_documen...
# 5e451298-d53a-4089-abd9-2d1ef721407c  {'question_type': 'situational', 'seed_documen...
# 9995d386-fc1f-4d3f-8abb-5667e2e3e58a  {'question_type': 'situational', 'seed_documen...
# 1804021f-4260-4c4b-bde4-7011b5bb936d  {'question_type': 'double', 'original_question...
# 98afe542-2142-4d23-aec4-6e8b523497f7  {'question_type': 'double', 'original_question...
# f50e4608-5aa7-47e8-975d-7fddf2f989db  {'question_type': 'conversational', 'seed_docu...
# 2ab5fabc-f970-4baf-a6ba-89d43e97ae62  {'question_type': 'conversational', 'seed_docu...
# 57de64ce-17a8-4585-9a98-2653bcb98932  {'question_type': 'conversational', 'seed_docu...
# 91e4ab38-5f4f-4a03-8a8b-9dc965e6e608  {'question_type': 'conversational', 'seed_docu...
# 62c9737e-e110-48a9-a282-881a258448cc  {'question_type': 'conversational', 'seed_docu...
# 44f564ce-9a45-4b97-96df-a34db9c4545e  {'question_type': 'conversational', 'seed_docu...
#
#                                                                            agent_answer  \
# id
# 21b81dea-8d65-4b4c-a501-e7e28fabce54  The topics covered in the second session of th...
# 70e621dd-1903-43ef-9737-bce15a9449e9  You'll come out with practical skills and insi...
# 6febe0b2-71a4-4f54-b12b-b5c910e9427e  The topics covered in the second session of th...
# 96922868-8c9c-4799-97d3-bb0f0a29df3b  Session 2 covered topics such as data cleaning...
# 321c31d4-e195-4dae-92d3-0f8c75cc07d6  You'll come out with practical skills and insi...
# 340a2da0-deba-416e-bb71-40227c528bd2                                         Juan Olano
# ed4c5c42-9abc-4afd-b8c9-b16c8d04d06d  The copyright for the content of the machine l...
# c0e9ccfb-3f6d-452b-946f-c09e79903825  The benefits of joining the machine learning p...
# 5e31f866-28da-4e68-9b36-ae9e44369efe  The benefits of joining the machine learning p...
# 44c909f2-e7a5-4776-a158-9f473c7ca075  The instructor of the Machine Learning School ...
# 0dedcd83-e131-4790-88b6-601c40b92d4e  The upcoming cohort for the machine learning p...
# 5e451298-d53a-4089-abd9-2d1ef721407c  The training program requires a minimum commit...
# 9995d386-fc1f-4d3f-8abb-5667e2e3e58a  The program at Machine Learning School only re...
# 1804021f-4260-4c4b-bde4-7011b5bb936d  The benefits of joining the Machine Learning S...
# 98afe542-2142-4d23-aec4-6e8b523497f7  The copyright for the content is held by Tidei...
# f50e4608-5aa7-47e8-975d-7fddf2f989db  This program could bring benefits such as prac...
# 2ab5fabc-f970-4baf-a6ba-89d43e97ae62  The benefits of this program include lifetime ...
# 57de64ce-17a8-4585-9a98-2653bcb98932                                      I don't know.
# 91e4ab38-5f4f-4a03-8a8b-9dc965e6e608  Some of the unique aspects of the program incl...
# 62c9737e-e110-48a9-a282-881a258448cc  This person is Santiago, and he is a machine l...
# 44f564ce-9a45-4b97-96df-a34db9c4545e  The benefits and features of the program inclu...
#
#                                       correctness  \
# id
# 21b81dea-8d65-4b4c-a501-e7e28fabce54        False
# 70e621dd-1903-43ef-9737-bce15a9449e9        False
# 6febe0b2-71a4-4f54-b12b-b5c910e9427e        False
# 96922868-8c9c-4799-97d3-bb0f0a29df3b        False
# 321c31d4-e195-4dae-92d3-0f8c75cc07d6        False
# 340a2da0-deba-416e-bb71-40227c528bd2        False
# ed4c5c42-9abc-4afd-b8c9-b16c8d04d06d        False
# c0e9ccfb-3f6d-452b-946f-c09e79903825        False
# 5e31f866-28da-4e68-9b36-ae9e44369efe        False
# 44c909f2-e7a5-4776-a158-9f473c7ca075        False
# 0dedcd83-e131-4790-88b6-601c40b92d4e        False
# 5e451298-d53a-4089-abd9-2d1ef721407c        False
# 9995d386-fc1f-4d3f-8abb-5667e2e3e58a        False
# 1804021f-4260-4c4b-bde4-7011b5bb936d        False
# 98afe542-2142-4d23-aec4-6e8b523497f7        False
# f50e4608-5aa7-47e8-975d-7fddf2f989db        False
# 2ab5fabc-f970-4baf-a6ba-89d43e97ae62        False
# 57de64ce-17a8-4585-9a98-2653bcb98932        False
# 91e4ab38-5f4f-4a03-8a8b-9dc965e6e608        False
# 62c9737e-e110-48a9-a282-881a258448cc        False
# 44f564ce-9a45-4b97-96df-a34db9c4545e        False
#
#                                                                      correctness_reason
# id
# 21b81dea-8d65-4b4c-a501-e7e28fabce54  The agent missed mentioning the zero-rule algo...
# 70e621dd-1903-43ef-9737-bce15a9449e9  The agent provided a very general answer, but ...
# 6febe0b2-71a4-4f54-b12b-b5c910e9427e  The agent missed mentioning 'normalization and...
# 96922868-8c9c-4799-97d3-bb0f0a29df3b  The agent missed mentioning the zero-rule algo...
# 321c31d4-e195-4dae-92d3-0f8c75cc07d6  The agent's answer was partially correct but i...
# 340a2da0-deba-416e-bb71-40227c528bd2  The agent stated that the instructor is Juan O...
# ed4c5c42-9abc-4afd-b8c9-b16c8d04d06d  The agent stated that the copyright belongs to...
# c0e9ccfb-3f6d-452b-946f-c09e79903825  The agent's answer focused on the technical as...
# 5e31f866-28da-4e68-9b36-ae9e44369efe  The agent's answer was partially correct, but ...
# 44c909f2-e7a5-4776-a158-9f473c7ca075  The agent provided a correct answer in terms o...
# 0dedcd83-e131-4790-88b6-601c40b92d4e  The agent failed to mention that the program l...
# 5e451298-d53a-4089-abd9-2d1ef721407c  The agent did not provide the correct duration...
# 9995d386-fc1f-4d3f-8abb-5667e2e3e58a  The agent did not provide the specific cost of...
# 1804021f-4260-4c4b-bde4-7011b5bb936d  The agent's answer is partially correct but it...
# 98afe542-2142-4d23-aec4-6e8b523497f7  The agent correctly identified the copyright h...
# f50e4608-5aa7-47e8-975d-7fddf2f989db  The agent provided a general overview of the b...
# 2ab5fabc-f970-4baf-a6ba-89d43e97ae62  The agent provided some correct benefits of th...
# 57de64ce-17a8-4585-9a98-2653bcb98932  The agent stated that it doesn't know the dura...
# 91e4ab38-5f4f-4a03-8a8b-9dc965e6e608  The agent mentioned designing and writing code...
# 62c9737e-e110-48a9-a282-881a258448cc  The agent provided correct information about S...
# 44f564ce-9a45-4b97-96df-a34db9c4545e  The agent provided a list of benefits and feat...

# %% [markdown]
# ## Creating a Test Suite
#
# We can create a test suite and use it to compare different models.

# %% [markdown]
# Load the test set from disk.

# %%
from giskard.rag import QATestset

testset = QATestset.load("test-set.jsonl")

# %% [markdown]
# Create a Test Suite from the test set.

# %%
test_suite = testset.to_test_suite("Machine Learning School Test Suite")

# %% [markdown]
# We need a function that takes a DataFrame of questions, invokes the chain with each question, and returns the answers.

# %%
import giskard


def batch_prediction_fn(df: pd.DataFrame):
    return chain.batch([{"question": q} for q in df["question"].values])

# %% [markdown]
# We can now create a Giskard Model object to run our test suite.

# %%
giskard_model = giskard.Model(
    model=batch_prediction_fn,
    model_type="text_generation",
    name="Machine Learning School Question and Answer Model",
    description="This model answers questions about the Machine Learning School website.",
    feature_names=["question"], 
)
# Out:
# 2024-11-07 18:58:02,726 pid:22380 MainThread giskard.models.automodel INFO     Your 'prediction_function' is successfully wrapped by Giskard's 'PredictionFunctionModel' wrapper class.

# %% [markdown]
# Let's now run the test suite using the model we created before.

# %%
test_suite_results = test_suite.run(model=giskard_model)
# Out:
# 2024-11-07 18:58:04,678 pid:22380 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'question': 'object'} to {'question': 'object'}
# 2024-11-07 18:58:12,516 pid:22380 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (60, 5) executed in 0:00:07.860728
# 2024-11-07 18:59:52,765 pid:22380 MainThread root         ERROR    An error happened during test execution for test: TestsetCorrectnessTest
# Traceback (most recent call last):
#   File "a:\github-profiles\turing\RAG\llm\venv\Lib\site-packages\giskard\core\suite.py", line 522, in run
#     result = test_partial.giskard_test(**test_params).execute()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "a:\github-profiles\turing\RAG\llm\venv\Lib\site-packages\giskard\registry\giskard_test.py", line 195, in execute
#     return configured_validate_arguments(self.test_fn)(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "a:\github-profiles\turing\RAG\llm\venv\Lib\site-packages\pydantic\validate_call_decorator.py", line 60, in wrapper_function
#     return validate_call_wrapper(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "a:\github-profiles\turing\RAG\llm\venv\Lib\site-packages\pydantic\_internal\_validate_call.py", line 96, in __call__
#     res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "a:\github-profiles\turing\RAG\llm\venv\Lib\site-packages\giskard\testing\tests\llm\correctness.py", line 50, in test_llm_correctness
#     details=eval_result.details,
#             ^^^^^^^^^^^^^^^^^^^
# AttributeError: 'EvaluationResult' object has no attribute 'details'
# 2024-11-07 18:59:52,767 pid:22380 MainThread giskard.core.suite INFO     Executed test suite 'Machine Learning School Test Suite'
# 2024-11-07 18:59:52,767 pid:22380 MainThread giskard.core.suite INFO     result: failed
# 2024-11-07 18:59:52,768 pid:22380 MainThread giskard.core.suite INFO     TestsetCorrectnessTest ({'model': <giskard.models.function.PredictionFunctionModel object at 0x000002F64E2DDFD0>, 'dataset': <giskard.datasets.base.Dataset object at 0x000002F67362AC90>}): {failed, metric=None}

# %% [markdown]
# We can display the results.

# %%
display(test_suite_results)
# Out:
# <TestSuiteResult (failed)>

# %% [markdown]
# ## Integrating with Pytest

# %%
import ipytest

# %% [markdown]
# We can now integrate our test suite with Pytest.

# %%
# %%ipytest
#
# import pytest
# from giskard.rag import QATestset
# from giskard.testing.tests.llm import test_llm_correctness
#
#
# @pytest.fixture
# def dataset():
#     testset = QATestset.load("test-set.jsonl")
#     return testset.to_dataset()
#
#
# @pytest.fixture
# def model():
#     return giskard_model
#
#
# def test_chain(dataset, model):
#     test_llm_correctness(model=model, dataset=dataset, threshold=0.5).assert_()
# Out:
# .2024-03-23 16:27:56,471 pid:46357 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'question': 'object'} to {'question': 'object'}
# 2024-03-23 16:27:56,472 pid:46357 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (60, 5) executed in 0:00:00.005269
# .                                                                                           [100%]
# ========================================= warnings summary =========================================
# ../.venv/lib/python3.9/site-packages/_pytest/config/__init__.py:1276
#   /Users/svpino/dev/llm/.venv/lib/python3.9/site-packages/_pytest/config/__init__.py:1276: PytestAssertRewriteWarning: Module already imported so cannot be rewritten: anyio
#     self._mark_plugins_for_rewrite(hook)
#
# t_66406511b9d84eb38baa6b0a22141dd0.py::test_llm_correctness
#   /Users/svpino/dev/llm/.venv/lib/python3.9/site-packages/_pytest/python.py:199: PytestReturnNotNoneWarning: Expected None, but t_66406511b9d84eb38baa6b0a22141dd0.py::test_llm_correctness returned To execute the test call "execute()" method, which will be an error in a future version of pytest.  Did you mean to use `assert` instead of `return`?
#     warnings.warn(
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# 2 passed, 2 warnings in 80.44s (0:01:20)
